# %% [markdown]
# # A demonstration on defining the vocabulary.

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# Setting the classification tolerance in ppm; dismissing entities below the intensity floor in <?>.

# %%
import os
import json
import pymzml
import numpy as np

INTENSITY_FLOOR = 10
TOLERANCE_FACTOR = 7

HOME_PATH = os.path.expanduser('~')
DATA_PATH = HOME_PATH + '/Projects/mlinb/tasks/defining_the_vocabulary/data/'
DATA_FILENAME = "abcdefgh_1.mzML"

# %% [markdown]
# An auxiliary method for classification within a certain range.

# %%
def classify(classes, feature):
    for class_ in classes:
        if feature >= class_[0] and feature <= class_[1]:
            return str(class_)

# %% [markdown]
# Downloading the data.

# %%
import urllib.request

URL = "https://www.dropbox.com/s/h89znvb6okbfebb/abcdefgh_1.mzML?dl=1"

if not os.path.exists(DATA_PATH):
    os.makedirs(DATA_PATH)

urllib.request.urlretrieve(URL, DATA_PATH + DATA_FILENAME)

# %% [markdown]
# ## Initialisation

# %% [markdown]
# Running the data.

# %%
run = pymzml.run.Reader(DATA_PATH + DATA_FILENAME)

# %% [markdown]
# Reading entities in the form of (mass, intensity) tuples.

# %%
preprocessed_mnis = []  
for spectrum in run:
    for mass, intensity in spectrum.peaks:
        if intensity > INTENSITY_FLOOR:
            preprocessed_mnis.append((mass, intensity, spectrum['id']))

# %% [markdown]
# Using numpy to sort the tuples in ascending mass order.

# %%
mnis_dtype = [('mass', float), ('intensity', float), ('id', int)]
mnis = np.array(preprocessed_mnis, dtype=mnis_dtype)
mnis.sort(order='mass')

# %% [markdown]
# ## Classification

# %% [markdown]
# Extracting the words.

# %%
words = []
starting_class_mass = mnis[0][0]
previous_mass = mnis[0][0]
for entity in mnis:
    mass = entity[0]
    tolerance = (previous_mass / 1000000) * TOLERANCE_FACTOR
    if mass - previous_mass > tolerance:
        words.append((starting_class_mass, previous_mass))
        starting_class_mass = mass
    previous_mass = mass 
words.append((starting_class_mass, previous_mass))

print(len(words))
# Out:
# 2442

# %% [markdown]
# Building the vocabulary.

# %%
corpus = {}
for entity in mnis:
    key = str(entity[2])
    if key not in corpus:
        corpus[key] = {}
    class_ = classify(words, entity[0])
    if class_ not in corpus[key]:
        corpus[key][class_] = 0
    corpus[key][class_] += entity[1]
    
print(len(corpus))
# Out:
# 6327

# %% [markdown]
# ## LDA

# %% [markdown]
# Importing the LDA.

# %%
import sys
sys.path.append(HOME_PATH + '/Projects/lda/code')
from lda import VariationalLDA

# %% [markdown]
# Initialising the LDA.

# %%
v_lda = VariationalLDA(corpus = corpus, K = 10) # corpus would be a better name than vocabulary
# Out:
# Found 2442 unique words
# Object created with 6327 documents

# %% [markdown]
# Running the LDA.

# %%
v_lda.run_vb(n_its = 100)
# Out:
# Initialising
# Starting iterations
# Iteration 0 (change = 12.2630226207) (12.762605 seconds, I think I'll finish in 21.2710083333 minutes)
# Iteration 1 (change = 0.158379570547) (11.695488 seconds, I think I'll finish in 19.2975552 minutes)
# Iteration 2 (change = 0.291422242113) (11.56731 seconds, I think I'll finish in 18.893273 minutes)
# Iteration 3 (change = 0.415132512274) (11.572065 seconds, I think I'll finish in 18.70817175 minutes)
# Iteration 4 (change = 0.528016208687) (11.712827 seconds, I think I'll finish in 18.7405232 minutes)
# Iteration 5 (change = 0.618927460205) (11.712385 seconds, I think I'll finish in 18.5446095833 minutes)
# Iteration 6 (change = 0.673600430646) (11.53889 seconds, I think I'll finish in 18.0775943333 minutes)
# Iteration 7 (change = 0.70309866495) (11.648023 seconds, I think I'll finish in 18.05443565 minutes)
# Iteration 8 (change = 0.695463176039) (11.89893 seconds, I think I'll finish in 18.245026 minutes)
# Iteration 9 (change = 0.658157969236) (11.942611 seconds, I think I'll finish in 18.1129600167 minutes)
# Iteration 10 (change = 0.601754396593) (11.606898 seconds, I think I'll finish in 17.410347 minutes)
# Iteration 11 (change = 0.534049808147) (11.791766 seconds, I think I'll finish in 17.4911195667 minutes)
# Iteration 12 (change = 0.461980135737) (11.809263 seconds, I think I'll finish in 17.3202524 minutes)
# Iteration 13 (change = 0.39601311365) (11.738566 seconds, I think I'll finish in 17.0209207 minutes)
# Iteration 14 (change = 0.344632625987) (12.090192 seconds, I think I'll finish in 17.3292752 minutes)
# Iteration 15 (change = 0.310760393428) (12.014852 seconds, I think I'll finish in 17.0210403333 minutes)
# Iteration 16 (change = 0.289276558853) (12.139576 seconds, I think I'll finish in 16.9954064 minutes)
# Iteration 17 (change = 0.27502193573) (12.057782 seconds, I think I'll finish in 16.6799317667 minutes)
# Iteration 18 (change = 0.265592565371) (12.445498 seconds, I think I'll finish in 17.0088472667 minutes)
# Iteration 19 (change = 0.259008169573) (12.117118 seconds, I think I'll finish in 16.3581093 minutes)
# Iteration 20 (change = 0.252676146172) (12.398716 seconds, I think I'll finish in 16.5316213333 minutes)
# Iteration 21 (change = 0.246197403046) (12.726904 seconds, I think I'll finish in 16.7570902667 minutes)
# Iteration 22 (change = 0.238174044622) (12.526404 seconds, I think I'll finish in 16.2843252 minutes)
# Iteration 23 (change = 0.229051549155) (12.633541 seconds, I think I'll finish in 16.2130442833 minutes)
# Iteration 24 (change = 0.219174309669) (12.665518 seconds, I think I'll finish in 16.0429894667 minutes)
# Iteration 25 (change = 0.208999850015) (12.588615 seconds, I think I'll finish in 15.73576875 minutes)
# Iteration 26 (change = 0.198695362264) (12.537828 seconds, I think I'll finish in 15.4633212 minutes)
# Iteration 27 (change = 0.18870842292) (12.511651 seconds, I think I'll finish in 15.2225087167 minutes)
# Iteration 28 (change = 0.179335050327) (12.781841 seconds, I think I'll finish in 15.3382092 minutes)
# Iteration 29 (change = 0.170415913995) (12.640524 seconds, I think I'll finish in 14.9579534 minutes)
# Iteration 30 (change = 0.162236210691) (12.787481 seconds, I think I'll finish in 14.9187278333 minutes)
# Iteration 31 (change = 0.154755506876) (12.748068 seconds, I think I'll finish in 14.6602782 minutes)
# Iteration 32 (change = 0.147617408796) (12.52334 seconds, I think I'll finish in 14.1931186667 minutes)
# Iteration 33 (change = 0.140724614767) (12.571799 seconds, I think I'll finish in 14.0385088833 minutes)
# Iteration 34 (change = 0.134125916562) (12.786085 seconds, I think I'll finish in 14.0646935 minutes)
# Iteration 35 (change = 0.127812757626) (12.887856 seconds, I think I'll finish in 13.961844 minutes)
# Iteration 36 (change = 0.121807673166) (12.900857 seconds, I think I'll finish in 13.7609141333 minutes)
# Iteration 37 (change = 0.116178918199) (12.857487 seconds, I think I'll finish in 13.50036135 minutes)
# Iteration 38 (change = 0.110893004876) (13.064854 seconds, I think I'll finish in 13.5003491333 minutes)
# Iteration 39 (change = 0.106026898471) (12.713969 seconds, I think I'll finish in 12.9258684833 minutes)
# Iteration 40 (change = 0.101595386976) (12.988227 seconds, I think I'll finish in 12.988227 minutes)
# Iteration 41 (change = 0.097557978323) (12.810891 seconds, I think I'll finish in 12.59737615 minutes)
# Iteration 42 (change = 0.0938585254808) (13.263536 seconds, I think I'll finish in 12.8214181333 minutes)
# Iteration 43 (change = 0.0903985536335) (12.928742 seconds, I think I'll finish in 12.2823049 minutes)
# Iteration 44 (change = 0.0871619983994) (13.266537 seconds, I think I'll finish in 12.3821012 minutes)
# Iteration 45 (change = 0.0841026032048) (13.210923 seconds, I think I'll finish in 12.11001275 minutes)
# Iteration 46 (change = 0.0812505153405) (13.151099 seconds, I think I'll finish in 11.8359891 minutes)
# Iteration 47 (change = 0.078620762343) (13.097388 seconds, I think I'll finish in 11.5693594 minutes)
# Iteration 48 (change = 0.0761549121891) (13.14132 seconds, I think I'll finish in 11.389144 minutes)
# Iteration 49 (change = 0.0738337125226) (13.085245 seconds, I think I'll finish in 11.12245825 minutes)
# Iteration 50 (change = 0.0717124315032) (13.12896 seconds, I think I'll finish in 10.9408 minutes)
# Iteration 51 (change = 0.0697688364069) (13.521859 seconds, I think I'll finish in 11.0428515167 minutes)
# Iteration 52 (change = 0.06794778654) (13.308635 seconds, I think I'll finish in 10.646908 minutes)
# Iteration 53 (change = 0.066232465392) (13.03199 seconds, I think I'll finish in 10.2083921667 minutes)
# Iteration 54 (change = 0.0645882592423) (13.017065 seconds, I think I'll finish in 9.97974983333 minutes)
# Iteration 55 (change = 0.063007300823) (13.489979 seconds, I think I'll finish in 10.11748425 minutes)
# Iteration 56 (change = 0.0614873127616) (13.181525 seconds, I think I'll finish in 9.66645166667 minutes)
# Iteration 57 (change = 0.0600303910112) (13.091363 seconds, I think I'll finish in 9.38214348333 minutes)
# Iteration 58 (change = 0.0586170896154) (13.123643 seconds, I think I'll finish in 9.1865501 minutes)
# Iteration 59 (change = 0.0572444285) (13.083033 seconds, I think I'll finish in 8.94007255 minutes)
# Iteration 60 (change = 0.0558970273445) (13.251991 seconds, I think I'll finish in 8.83466066667 minutes)
# Iteration 61 (change = 0.0545570979656) (13.110201 seconds, I think I'll finish in 8.52163065 minutes)
# Iteration 62 (change = 0.0532395856724) (13.476137 seconds, I think I'll finish in 8.53488676667 minutes)
# Iteration 63 (change = 0.051951052262) (13.345435 seconds, I think I'll finish in 8.22968491667 minutes)
# Iteration 64 (change = 0.0506849325256) (13.420722 seconds, I think I'll finish in 8.0524332 minutes)
# Iteration 65 (change = 0.0494345987549) (13.355553 seconds, I think I'll finish in 7.79073925 minutes)
# Iteration 66 (change = 0.04819975846) (13.350043 seconds, I think I'll finish in 7.56502436667 minutes)
# Iteration 67 (change = 0.0470055224074) (13.244089 seconds, I think I'll finish in 7.28424895 minutes)
# Iteration 68 (change = 0.0458458206058) (13.32372 seconds, I think I'll finish in 7.105984 minutes)
# Iteration 69 (change = 0.0447226858356) (13.19883 seconds, I think I'll finish in 6.8193955 minutes)
# Iteration 70 (change = 0.0436453844075) (13.231144 seconds, I think I'll finish in 6.615572 minutes)
# Iteration 71 (change = 0.0426314186165) (13.627348 seconds, I think I'll finish in 6.58655153333 minutes)
# Iteration 72 (change = 0.0416409497887) (13.377027 seconds, I think I'll finish in 6.2426126 minutes)
# Iteration 73 (change = 0.0406702463474) (13.022468 seconds, I think I'll finish in 5.8601106 minutes)
# Iteration 74 (change = 0.0397244522125) (13.362592 seconds, I think I'll finish in 5.79045653333 minutes)
# Iteration 75 (change = 0.0388028410818) (13.24242 seconds, I think I'll finish in 5.517675 minutes)
# Iteration 76 (change = 0.0379076388169) (13.423205 seconds, I think I'll finish in 5.369282 minutes)
# Iteration 77 (change = 0.0370388731963) (13.158692 seconds, I think I'll finish in 5.04416526667 minutes)
# Iteration 78 (change = 0.0362044214276) (13.353007 seconds, I think I'll finish in 4.89610256667 minutes)
# Iteration 79 (change = 0.0354500344084) (13.380675 seconds, I think I'll finish in 4.68323625 minutes)
# Iteration 80 (change = 0.0347401281425) (13.403522 seconds, I think I'll finish in 4.46784066667 minutes)
# Iteration 81 (change = 0.0340572256132) (13.258442 seconds, I think I'll finish in 4.19850663333 minutes)
# Iteration 82 (change = 0.0333946409196) (13.916059 seconds, I think I'll finish in 4.1748177 minutes)
# Iteration 83 (change = 0.0327482047075) (13.054609 seconds, I think I'll finish in 3.69880588333 minutes)
# Iteration 84 (change = 0.0321141693286) (13.144522 seconds, I think I'll finish in 3.50520586667 minutes)
# Iteration 85 (change = 0.0314974664974) (13.172342 seconds, I think I'll finish in 3.2930855 minutes)
# Iteration 86 (change = 0.0308901723615) (13.273271 seconds, I think I'll finish in 3.09709656667 minutes)
# Iteration 87 (change = 0.0302929718301) (13.30461 seconds, I think I'll finish in 2.8826655 minutes)
# Iteration 88 (change = 0.0297117820496) (13.252914 seconds, I think I'll finish in 2.6505828 minutes)
# Iteration 89 (change = 0.0291457362012) (13.123202 seconds, I think I'll finish in 2.40592036667 minutes)
# Iteration 90 (change = 0.0285912160302) (13.154048 seconds, I think I'll finish in 2.19234133333 minutes)
# Iteration 91 (change = 0.0280564703061) (13.191062 seconds, I think I'll finish in 1.9786593 minutes)
# Iteration 92 (change = 0.0275430370726) (13.090248 seconds, I think I'll finish in 1.7453664 minutes)
# Iteration 93 (change = 0.0270459750369) (13.26367 seconds, I think I'll finish in 1.54742816667 minutes)
# Iteration 94 (change = 0.026564549848) (13.291975 seconds, I think I'll finish in 1.3291975 minutes)
# Iteration 95 (change = 0.0261008245281) (13.301865 seconds, I think I'll finish in 1.10848875 minutes)
# Iteration 96 (change = 0.0256538425174) (13.387073 seconds, I think I'll finish in 0.892471533333 minutes)
# Iteration 97 (change = 0.0252213442426) (13.271542 seconds, I think I'll finish in 0.6635771 minutes)
# Iteration 98 (change = 0.0248022672219) (13.059379 seconds, I think I'll finish in 0.435312633333 minutes)
# Iteration 99 (change = 0.0243962855927) (13.426064 seconds, I think I'll finish in 0.223767733333 minutes)

# %%
topic_as_dict = v_lda.get_topic_as_dict(0)

print(topic_as_dict)
# Out:
# {'(151.09847872359833, 151.14774846579857)': 1.5393106839369105e-05, '(1172.055956896874, 1172.1804047037635)': 1.5969584910656512e-06, '(277.98797509867501, 278.06580782869469)': 2.5163647624259175e-05, '(1740.5028626970227, 1747.0751096451438)': 0.00017658605975382353, '(272.12429753288126, 272.16606638851204)': 3.1577590358407075e-09, '(198.06762349229547, 198.13858880026723)': 9.0920606733219903e-05, '(381.73894958401314, 382.77873954256165)': 7.1919521190346808e-05, '(968.06467060484977, 968.08721790753862)': 4.9227901765333674e-10, '(263.75916279237083, 263.77428016266151)': 1.2755438504644066e-09, '(441.03770890187093, 441.74079945490018)': 0.0050324103693776901, '(310.06312272346935, 310.59277614054275)': 0.0063041029493050883, '(497.75772377031421, 498.02028078441288)': 1.5554035219248046e-08, '(559.18461300940112, 559.97023876067703)': 4.5652014990580611e-05, '(540.50293221564391, 540.8740077319593)': 7.2189988294892034e-07, '(555.89736620968199, 556.07120554024232)': 1.9462062422395775e-05, '(329.39202320241634, 329.43997564535005)': 2.8832408593509513e-09, '(216.47675289226663, 216.52580813911075)': 1.2401674786877802e-08, '(155.14480906525327, 155.25315106052352)': 4.5538734762041754e-05, '(519.88573088276166, 520.19263452937696)': 8.0646377258711295e-07, '(573.7242749916287, 574.93268957309795)': 0.00012625283545662327, '(747.93601292593064, 750.99016390703252)': 6.6142325112018231e-05, '(311.50442007932457, 311.59909906775709)': 1.835764109420286e-09, '(216.83448881376145, 216.91509305479178)': 1.4243746702748287e-09, '(647.01325751125967, 647.12414911456563)': 1.1414627587967935e-08, '(960.42173295899499, 960.99172861698787)': 7.1490793112322597e-05, '(399.52964759546626, 399.97324079978398)': 5.4662998797275267e-07, '(547.62746966598775, 547.68777406114009)': 1.4839860037042429e-09, '(479.66880754226707, 479.69801797422861)': 1.2471944160069947e-05, '(559.97590693489065, 560.15308079665112)': 3.4767317514958601e-05, '(295.89934167522676, 295.98481727743888)': 1.8765658363810772e-05, '(416.46432878161136, 416.67617504788342)': 1.056870913441407e-08, '(1231.4320257522716, 1232.532590740328)': 1.3008938982172718e-06, '(1210.0328140829752, 1216.6541148072106)': 2.0220400392543343e-06, '(482.8061172258349, 482.82653827272867)': 1.8306267124511869e-08, '(391.81306287317665, 391.94164761519693)': 1.987342818617409e-05, '(1063.4398225860152, 1064.2376047213043)': 3.0595625169394745e-08, '(317.56599986412965, 317.9348746018585)': 2.2156367298827312e-08, '(398.68723362338812, 398.70085472051392)': 7.2348051044586262e-10, '(383.71826748450883, 384.10438549848334)': 4.1425356706648133e-09, '(1603.66095047866, 1611.0621979819673)': 9.0010030889174303e-05, '(217.46172090606106, 217.90684143679826)': 5.0196522706946571e-06, '(157.86636269090064, 158.09314310254709)': 1.3009085877013312e-06, '(353.73540071859321, 354.04081453681624)': 5.7311812299173086e-06, '(206.15248778217025, 206.44463876923481)': 0.0012235372156386339, '(339.0232932858508, 339.42617818411776)': 0.00062138879454115548, '(601.99725775988213, 602.50302167403026)': 7.7651902549015206e-09, '(323.39234493826558, 323.5951827477985)': 1.6246806674694515e-09, '(539.95240143423712, 540.38201189291499)': 1.4385741938579068e-05, '(638.07312133875939, 638.22827424198499)': 1.0953934474137859e-05, '(155.32081895099981, 155.35290939696782)': 1.5345385494325054e-09, '(627.04740557046421, 627.18007751784103)': 1.2836652607011041e-05, '(915.10205613120434, 915.24712837843754)': 3.6572419755323164e-08, '(516.95976035185458, 517.04021448928017)': 6.8515898648124446e-06, '(197.63995697582897, 197.66283785638697)': 1.1074744436765688e-06, '(510.90346831991059, 511.05786904200926)': 1.2071457143490547e-09, '(226.79085749702799, 226.84309490709063)': 1.9010583464525476e-05, '(1115.7162719828793, 1116.4140294776023)': 7.133601420708246e-05, '(365.90189736031937, 366.07186123990931)': 5.3090696805245606e-05, '(196.79260666676026, 196.82213195944905)': 7.4278105938584446e-08, '(19 ...
