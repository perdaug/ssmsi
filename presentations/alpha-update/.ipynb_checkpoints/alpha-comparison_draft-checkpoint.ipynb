# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
np.set_printoptions(threshold=np.nan)
import matplotlib.pyplot as plt
# %matplotlib inline
import string

def softmax(arr):
    return np.exp(arr) / np.sum(np.exp(arr))

# Corpus parameters
K = 2
xi = 1000 # Approximate number of words
T = 20
linspace_t = np.linspace(0, T-1, num=T)
V = 10

# Initialise the vocabulary
vocab = []
for w in range(V):
    vocab.append(string.ascii_lowercase[w])

prior_dirichlet = np.repeat(1./V, V)
beta = np.random.dirichlet(prior_dirichlet, K)
beta = np.array([[0, 0, 0, 0.3, 0.7, 0, 0, 0, 0, 0], [0, 0, 0.2, 0, 0, 0, 0, 0.3, 0.3, 0.2]])
# print beta[0].sum()
alphas = np.zeros((T, K))
linspace_4pi = np.linspace(0, 4*np.pi, num=T)
alphas[:,0] = np.sin(linspace_4pi) 
alphas[:,1] = np.cos(linspace_4pi) 

corpus = {}
for d in range(T):
    corpus[d] = {}
    N = np.random.poisson(xi)
    for w in range(N):
#         eta = softmax(alphas[d])
#         topic_distrib = np.random.multinomial(1, eta)
        topic_distrib = np.random.multinomial(1, alphas[d])
        z = np.where(topic_distrib == 1)[0][0]
        word_distrib = np.random.multinomial(1, beta[z])
        w = np.where(word_distrib == 1)[0][0]
        w_key = vocab[w]
        if w_key not in corpus[d]:
            corpus[d][w_key] = 0
        corpus[d][w_key] += 1

from preprocessing import preprocess_corpus
count_max = 200.
normalise = False
corpus = preprocess_corpus(corpus, vocab, threshold=count_max, normalise=normalise)
corpus.dump('corpus_test.pkl')

# %%
# Plot betas
linspace_V = np.linspace(0, V-1, num=V)
plt.figure(1)

plt.plot(linspace_V, beta[0], linewidth=2, label='k=0')
plt.plot(linspace_V, beta[1], linewidth=2, label='k=1')
plt.legend(loc=1)
plt.xlabel('V')
plt.ylabel(r'$\beta$')

# %%
# Plot alphas
alphas_softmax = np.zeros(shape=alphas.shape)
for t, alpha_t in enumerate(alphas):
    alphas_softmax[t] = softmax(alpha_t)
plt.plot(linspace_t, alphas_softmax, linewidth=2)
plt.xlabel('T')
plt.ylabel(r'softmax($\alpha$)')
plt.savefig('mu.png')

# %% [markdown]
# ### Fit

# %%
from dtm_autoreg import DTM_Alpha

n_it = 500
var_init = 0.5
var_basic = 0.1
var_prop = 1
dtm_alpha = DTM_Alpha(K=K, sigma_0_sq=var_init, sigma_sq=var_basic, 
        delta_sq=var_prop)
dtm_alpha.beta = beta
dtm_alpha.fit(corpus=corpus, n_it=n_it)
# Out:
# Iteration: 10
# Total alpha changes: 199
# Alpha update rate: 0.4975
# Iteration: 20
# Total alpha changes: 400
# Alpha update rate: 0.5000
# Iteration: 30
# Total alpha changes: 590
# Alpha update rate: 0.4917
# Iteration: 40
# Total alpha changes: 760
# Alpha update rate: 0.4750
# Iteration: 50
# Total alpha changes: 958
# Alpha update rate: 0.4790
# Iteration: 60
# Total alpha changes: 1154
# Alpha update rate: 0.4808
# Iteration: 70
# Total alpha changes: 1338
# Alpha update rate: 0.4779
# Iteration: 80
# Total alpha changes: 1544
# Alpha update rate: 0.4825
# Iteration: 90
# Total alpha changes: 1746
# Alpha update rate: 0.4850
# Iteration: 100
# Total alpha changes: 1951
# Alpha update rate: 0.4878
# Iteration: 110
# Total alpha changes: 2129
# Alpha update rate: 0.4839
# Iteration: 120
# Total alpha changes: 2343
# Alpha update rate: 0.4881
# Iteration: 130
# Total alpha changes: 2531
# Alpha update rate: 0.4867
# Iteration: 140
# Total alpha changes: 2718
# Alpha update rate: 0.4854
# Iteration: 150
# Total alpha changes: 2911
# Alpha update rate: 0.4852
# Iteration: 160
# Total alpha changes: 3099
# Alpha update rate: 0.4842
# Iteration: 170
# Total alpha changes: 3283
# Alpha update rate: 0.4828
# Iteration: 180
# Total alpha changes: 3481
# Alpha update rate: 0.4835
# Iteration: 190
# Total alpha changes: 3678
# Alpha update rate: 0.4839
# Iteration: 200
# Total alpha changes: 3860
# Alpha update rate: 0.4825
# Iteration: 210
# Total alpha changes: 4057
# Alpha update rate: 0.4830
# Iteration: 220
# Total alpha changes: 4244
# Alpha update rate: 0.4823
# Iteration: 230
# Total alpha changes: 4443
# Alpha update rate: 0.4829
# Iteration: 240
# Total alpha changes: 4636
# Alpha update rate: 0.4829
# Iteration: 250
# Total alpha changes: 4829
# Alpha update rate: 0.4829
# Iteration: 260
# Total alpha changes: 5004
# Alpha update rate: 0.4812
# Iteration: 270
# Total alpha changes: 5197
# Alpha update rate: 0.4812
# Iteration: 280
# Total alpha changes: 5376
# Alpha update rate: 0.4800
# Iteration: 290
# Total alpha changes: 5559
# Alpha update rate: 0.4792
# Iteration: 300
# Total alpha changes: 5758
# Alpha update rate: 0.4798
# Iteration: 310
# Total alpha changes: 5954
# Alpha update rate: 0.4802
# Iteration: 320
# Total alpha changes: 6141
# Alpha update rate: 0.4798
# Iteration: 330
# Total alpha changes: 6300
# Alpha update rate: 0.4773
# Iteration: 340
# Total alpha changes: 6490
# Alpha update rate: 0.4772
# Iteration: 350
# Total alpha changes: 6687
# Alpha update rate: 0.4776
# Iteration: 360
# Total alpha changes: 6869
# Alpha update rate: 0.4770
# Iteration: 370
# Total alpha changes: 7062
# Alpha update rate: 0.4772
# Iteration: 380
# Total alpha changes: 7268
# Alpha update rate: 0.4782
# Iteration: 390
# Total alpha changes: 7451
# Alpha update rate: 0.4776
# Iteration: 400
# Total alpha changes: 7639
# Alpha update rate: 0.4774
# Iteration: 410
# Total alpha changes: 7818
# Alpha update rate: 0.4767
# Iteration: 420
# Total alpha changes: 8002
# Alpha update rate: 0.4763
# Iteration: 430
# Total alpha changes: 8194
# Alpha update rate: 0.4764
# Iteration: 440
# Total alpha changes: 8377
# Alpha update rate: 0.4760
# Iteration: 450
# Total alpha changes: 8573
# Alpha update rate: 0.4763
# Iteration: 460
# Total alpha changes: 8764
# Alpha update rate: 0.4763
# Iteration: 470
# Total alpha changes: 8950
# Alpha update rate: 0.4761
# Iteration: 480
# Total alpha changes: 9149
# Alpha update rate: 0.4765
# Iteration: 490
# Total alpha changes: 9338
# Alpha update rate: 0.4764

# %% [markdown]
# ### Print and dump

# %%
# Calculate the softmax
history_alpha = dtm_alpha.hist_alpha
labels = []
curves = []
settings = []
colours = ['orange', 'b']
styles = ['-', '--', 'o']
for it in xrange(0, 3):
    idx = n_it - 1 - it * 50
    alphas_last_proposed = history_alpha[idx-1]
    alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
    for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
        alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)
    alphas_softmax_last_proposed = alphas_softmax_last_proposed.T
    for id_label, alpha in enumerate(alphas_softmax_last_proposed):
        curves.append(alpha)
        settings.append((colours[id_label],1-(it*0.33),styles[id_label]))
        labels.append('k=%d, it=%d' % (id_label, idx))

# Plot the figure
from matplotlib.ticker import MaxNLocator
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

for y_arr, label, setting in zip(curves, labels, settings):
    plt.plot(linspace_t, y_arr, label=label, color=setting[0], alpha=setting[1], ls=settings[2])
title_fig = r'$\sigma_0^2=%.2f,\quad \sigma^2=%.2f,\quad \delta^2=%.1f$' \
        % (var_init, var_basic, var_prop)
plt.title(title_fig)
plt.legend(loc=1)
plt.xlabel('t')
plt.ylabel(r'softmax($\alpha)$')

# Save the plot and the model
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d' \
        % (var_init, var_basic, var_prop, n_it)
plt.savefig('results/' + name_model_out + '.png', dpi=900)
vars_dtm = vars(dtm_alpha)
with open('models/' + name_model_out + '.pkl', 'wb') as f:
        pkl.dump(vars_dtm, f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-e52e0347a8ae> in <module>()
#      24
#      25 for y_arr, label, setting in zip(curves, labels, settings):
# ---> 26     plt.plot(linspace_t, y_arr, label=label, color=setting[0], alpha=setting[1], ls=settings[2])
#      27 title_fig = r'$\sigma_0^2=%.2f,\quad \sigma^2=%.2f,\quad \delta^2=%.1f$'         % (var_init, var_basic, var_prop)
#      28 plt.title(title_fig)
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     405                 return
#     406             if len(remaining) <= 3:
# --> 407                 for seg in self._plot_args(remaining, kwargs):
#     408                     yield seg
#     409                 return
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     393         ncx, ncy = x.shape[1], y.shape[1]
#     394         for j in xrange(max(ncx, ncy)):
# --> 395             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     396             ret.append(seg)
#     397         return ret
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _makeline(self, x, y, kw, kwargs)
#     300         default_dict = self._getdefaults(None, kw)
#     301         self._setdefaults(default_dict, kw)
# --> 302         seg = mlines.Line2D(x, y, **kw)
#     303         return seg
#     304
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     396         self._us_dashOffset = 0
#     397
# --> 398         self.set_linestyle(linestyle)
#     399         self.set_drawstyle(drawstyle)
#     400         self.set_linewidth(linewidth)
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/lines.pyc in set_linestyle(self, ls)
#    1149
#    1150         # get the unscaled dashes
# -> 1151         self._us_dashOffset, self._us_dashSeq = _get_dash_pattern(ls)
#    1152         # compute the linewidth scaled dashes
#    1153         self._dashOffset, self._dashSeq = _scale_dashes(
#
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/lines.pyc in _get_dash_pattern(style)
#      53     #
#      54     elif isinstance(style, tuple):
# ---> 55         offset, dashes = style
#      56     else:
#      57         raise ValueError('Unrecognized linestyle: %s' % str(style))
#
# ValueError: too many values to unpack

# %% [markdown]
# ### Load, fit, and dump

# %%
# from dtm_alpha import DTM_Alpha

n_it = 250
n_it_add = 15
var_init = 0.5
var_basic = 0.1
var_prop = 1
name_model_in = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d' \
        % (var_init, var_basic, var_prop, n_it)
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d' \
        % (var_init, var_basic, var_prop, n_it + n_it_add)

dtm_alpha = DTM_Alpha()
dtm_alpha.load_fit('models/' + name_model_in + '.pkl', n_it=n_it_add)

history_alpha = dtm_alpha.hist_alpha
alphas_last_proposed = history_alpha[n_it-1]
alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
    alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)

plt.plot(linspace_t, alphas_softmax_last_proposed, linewidth=2)


plt.savefig('results/' + name_model_out + '.png')
vars_dtm = vars(dtm_alpha)
with open('models/' + name_model_out + '.pkl', 'wb') as f:
        pkl.dump(vars_dtm, f)
# Out:
# Iteration: 250
# Total alpha changes: 4683
# Alpha update rate: 0.4683
# Iteration: 260
# Total alpha changes: 4866
# Alpha update rate: 0.4679
# /Applications/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly.graph_objs as go

alphas_softmax_proposed = np.zeros(shape=history_alpha.shape)

diff_min = 10000
idx_min = -1
for it, alpha_it in enumerate(history_alpha):
    for t, alpha_proposed_t in enumerate(alpha_it):
        alphas_softmax_proposed[it][t] = softmax(alpha_proposed_t)
    diff_abs = np.abs(alphas_softmax - alphas_softmax_proposed[it]).sum()
    if diff_abs < diff_min:
        diff_min = diff_abs
        idx_min = it
    
n_alphas = alphas_softmax_proposed.shape[2]
list_alphas = []
for i in range(n_alphas):
    alpha = dict(z = alphas_softmax_proposed[:, :, i], type='surface')
    list_alphas.append(alpha)
fig = go.Figure(data=list_alphas)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perdaugmazas/325.embed" height="525px" width="100%"></iframe>

# %%
print diff_min
print idx_min
# Out:
# 6.91030980045
# 70

# %%
alphas_last_proposed = history_alpha[50]
alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
    alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)
plt.plot(linspace_t, alphas_softmax_last_proposed, linewidth=2)
# plt.plot(linspace_t, history_alpha[iter_count-1], linewidth=2)
# plt.savefig('results/var-init-%.1f_var-prop-%.1f_it-total-%d_it-min-%d.png' % (var_init, var_prop, iter_count, idx_min))
# Out:
# [<matplotlib.lines.Line2D at 0x7efd50212710>,
#  <matplotlib.lines.Line2D at 0x7efd50212910>]

# %%
thetas = pd.read_pickle('thetas.pkl')
plt.plot(linspace_t, thetas[499], linewidth=2)
plt.savefig('thetas.png')
