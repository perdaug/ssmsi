# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
np.set_printoptions(threshold=np.nan)
import matplotlib.pyplot as plt
# %matplotlib inline
import string

def softmax(arr):
    return np.exp(arr) / np.sum(np.exp(arr))

# Corpus parameters
K = 2
xi = 1000 # Approximate number of words
T = 20
V = 10
var_init = 1
var_basic = 0.1

# Initialise the vocabulary
vocab = []
for w in range(V):
    vocab.append(string.ascii_lowercase[w])

prior_dirichlet = np.repeat(1./V, V)
beta = np.random.dirichlet(prior_dirichlet, K)
beta = np.array([[0, 0, 0, 0.3, 0.7, 0, 0, 0, 0, 0], [0, 0, 0.2, 0, 0, 0, 0, 0.3, 0.3, 0.2]])
# print beta[0].sum()
alphas = np.zeros((T, K))
linspace_4pi = np.linspace(0, 4*np.pi, num=T)
alphas[:,0] = np.sin(linspace_4pi) 
alphas[:,1] = np.cos(linspace_4pi) 

corpus = {}
for d in range(T):
    corpus[d] = {}
    N = np.random.poisson(xi)
    for w in range(N):
#         eta = softmax(alphas[d])
#         topic_distrib = np.random.multinomial(1, eta)
        topic_distrib = np.random.multinomial(1, alphas[d])
        z = np.where(topic_distrib == 1)[0][0]
        word_distrib = np.random.multinomial(1, beta[z])
        w = np.where(word_distrib == 1)[0][0]
        w_key = vocab[w]
        if w_key not in corpus[d]:
            corpus[d][w_key] = 0
        corpus[d][w_key] += 1

from preprocessing import preprocess_corpus
count_max = 200.
normalise = False
corpus = preprocess_corpus(corpus, vocab, threshold=count_max, normalise=normalise)

# %%
# Plot betas
linspace_V = np.linspace(0, V-1, num=V)
plt.plot(linspace_V, beta[0], linewidth=2)
plt.plot(linspace_V, beta[1], linewidth=2)
print zip(linspace_V, vocab)
# Out:
# [(0.0, 'a'), (1.0, 'b'), (2.0, 'c'), (3.0, 'd'), (4.0, 'e'), (5.0, 'f'), (6.0, 'g'), (7.0, 'h'), (8.0, 'i'), (9.0, 'j')]

# %%
from dtm_alpha import DTM_alpha

iter_count = 500
var_init = 5
var_basic = 0.1
var_prop = 2

dtm_alpha = DTM_alpha(K=K, iter_count=iter_count, var_init=var_init, var_basic=var_basic, var_prop=var_prop)
dtm_alpha.beta = beta
dtm_alpha.fit(corpus)

history_alpha = dtm_alpha.history_alpha
# Out:
# Iteration: 10
# Total alpha changes: 56
# Alpha update rate: 0.2800
# Iteration: 20
# Total alpha changes: 93
# Alpha update rate: 0.2325
# Iteration: 30
# Total alpha changes: 128
# Alpha update rate: 0.2133
# Iteration: 40
# Total alpha changes: 161
# Alpha update rate: 0.2013
# Iteration: 50
# Total alpha changes: 193
# Alpha update rate: 0.1930
# Iteration: 60
# Total alpha changes: 224
# Alpha update rate: 0.1867
# Iteration: 70
# Total alpha changes: 253
# Alpha update rate: 0.1807
# Iteration: 80
# Total alpha changes: 283
# Alpha update rate: 0.1769
# Iteration: 90
# Total alpha changes: 311
# Alpha update rate: 0.1728
# Iteration: 100
# Total alpha changes: 338
# Alpha update rate: 0.1690
# Iteration: 110
# Total alpha changes: 368
# Alpha update rate: 0.1673
# Iteration: 120
# Total alpha changes: 399
# Alpha update rate: 0.1663
# Iteration: 130
# Total alpha changes: 431
# Alpha update rate: 0.1658
# Iteration: 140
# Total alpha changes: 467
# Alpha update rate: 0.1668
# Iteration: 150
# Total alpha changes: 497
# Alpha update rate: 0.1657
# Iteration: 160
# Total alpha changes: 534
# Alpha update rate: 0.1669
# Iteration: 170
# Total alpha changes: 567
# Alpha update rate: 0.1668
# Iteration: 180
# Total alpha changes: 598
# Alpha update rate: 0.1661
# Iteration: 190
# Total alpha changes: 629
# Alpha update rate: 0.1655
# Iteration: 200
# Total alpha changes: 661
# Alpha update rate: 0.1653
# Iteration: 210
# Total alpha changes: 693
# Alpha update rate: 0.1650
# Iteration: 220
# Total alpha changes: 725
# Alpha update rate: 0.1648
# Iteration: 230
# Total alpha changes: 760
# Alpha update rate: 0.1652
# Iteration: 240
# Total alpha changes: 798
# Alpha update rate: 0.1663
# Iteration: 250
# Total alpha changes: 835
# Alpha update rate: 0.1670
# Iteration: 260
# Total alpha changes: 869
# Alpha update rate: 0.1671
# Iteration: 270
# Total alpha changes: 906
# Alpha update rate: 0.1678
# Iteration: 280
# Total alpha changes: 947
# Alpha update rate: 0.1691
# Iteration: 290
# Total alpha changes: 984
# Alpha update rate: 0.1697
# Iteration: 300
# Total alpha changes: 1020
# Alpha update rate: 0.1700
# Iteration: 310
# Total alpha changes: 1053
# Alpha update rate: 0.1698
# Iteration: 320
# Total alpha changes: 1086
# Alpha update rate: 0.1697
# Iteration: 330
# Total alpha changes: 1125
# Alpha update rate: 0.1705
# Iteration: 340
# Total alpha changes: 1163
# Alpha update rate: 0.1710
# Iteration: 350
# Total alpha changes: 1201
# Alpha update rate: 0.1716
# Iteration: 360
# Total alpha changes: 1240
# Alpha update rate: 0.1722
# Iteration: 370
# Total alpha changes: 1274
# Alpha update rate: 0.1722
# Iteration: 380
# Total alpha changes: 1302
# Alpha update rate: 0.1713
# Iteration: 390
# Total alpha changes: 1335
# Alpha update rate: 0.1712
# Iteration: 400
# Total alpha changes: 1366
# Alpha update rate: 0.1708
# Iteration: 410
# Total alpha changes: 1399
# Alpha update rate: 0.1706
# Iteration: 420
# Total alpha changes: 1434
# Alpha update rate: 0.1707
# Iteration: 430
# Total alpha changes: 1467
# Alpha update rate: 0.1706
# Iteration: 440
# Total alpha changes: 1505
# Alpha update rate: 0.1710
# Iteration: 450
# Total alpha changes: 1545
# Alpha update rate: 0.1717
# Iteration: 460
# Total alpha changes: 1582
# Alpha update rate: 0.1720
# Iteration: 470
# Total alpha changes: 1618
# Alpha update rate: 0.1721
# Iteration: 480
# Total alpha changes: 1653
# Alpha update rate: 0.1722
# Iteration: 490
# Total alpha changes: 1688
# Alpha update rate: 0.1722

# %%
# Plot alphas
linspace_t = np.linspace(0, T-1, num=T)
alphas_softmax = np.zeros(shape=alphas.shape)
for t, alpha_t in enumerate(alphas):
    alphas_softmax[t] = softmax(alpha_t)
plt.plot(linspace_t, alphas_softmax, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f6c4c3b57d0>,
#  <matplotlib.lines.Line2D at 0x7f6c4c3b59d0>]

# %%
alphas_last_proposed = history_alpha[iter_count-1]
alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
    alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)
print alphas_softmax_last_proposed
plt.plot(linspace_t, alphas_softmax_last_proposed, linewidth=2)
# plt.plot(linspace_t, history_alpha[iter_count-1], linewidth=2)
plt.savefig('results/var-init-%.1f_var-prop%.1f_iter%d.png' % (var_init, var_prop, iter_count))
# Out:
# [[ 0.00417597  0.99582403]
#  [ 0.71203453  0.28796547]
#  [ 0.91566987  0.08433013]
#  [ 0.97761822  0.02238178]
#  [ 0.99342911  0.00657089]
#  [ 0.38056091  0.61943909]
#  [ 0.1418756   0.8581244 ]
#  [ 0.02497037  0.97502963]
#  [ 0.01883574  0.98116426]
#  [ 0.03088051  0.96911949]
#  [ 0.26609042  0.73390958]
#  [ 0.82674144  0.17325856]
#  [ 0.93074467  0.06925533]
#  [ 0.9667105   0.0332895 ]
#  [ 0.33886033  0.66113967]
#  [ 0.1179005   0.8820995 ]
#  [ 0.03506314  0.96493686]
#  [ 0.01811233  0.98188767]
#  [ 0.00766145  0.99233855]
#  [ 0.00658138  0.99341862]]
# [<matplotlib.lines.Line2D at 0x7f6c49e17510>,
#  <matplotlib.lines.Line2D at 0x7f6c49e17710>]

# %%
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly.graph_objs as go

n_alphas = history_alpha.shape[2]
list_alphas = []
for i in range(n_alphas):
    alpha = dict(z = history_alpha[:, :, i], type='surface')
    list_alphas.append(alpha)
fig = go.Figure(data=list_alphas)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perdaugmazas/257.embed" height="525px" width="100%"></iframe>
