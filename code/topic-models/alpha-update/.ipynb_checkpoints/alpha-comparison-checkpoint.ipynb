# %% [markdown]
# ## Generate a corpus

# %% [markdown]
# #### Initialisation

# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
np.set_printoptions(threshold=np.nan)

def softmax(arr):
    return np.exp(arr) / np.sum(np.exp(arr))

# Corpus parameters
K = 2
xi = 1000 # Approximate number of words
T = 25
V = 10
alphas = np.zeros((T, K))
betas = np.zeros((T, K, V))
var_init = 1
var_basic = 0.1

# Initialise the vocabulary
import string
vocab = []
for w in range(V):
    vocab.append(string.ascii_lowercase[w])

# Initialise the parameters at t=0
beta_0 = np.zeros((K, V))
for k, beta_0_k in enumerate(beta_0):
    beta_0[k] = np.random.normal(beta_0_k, var_init)
    
betas[0] = beta_0
for t in xrange (1, T):
    betas[t] = np.random.normal(betas[t-1], var_basic)
    
alphas[0] = np.random.normal(alphas[0], var_init)
for t in xrange (1, T):
    alphas[t] = np.random.normal(alphas[t-1], var_basic)

# %% [markdown]
# #### Corpus generation

# %%
corpus = {}
for d in range(T):
    corpus[d] = {}
    N = np.random.poisson(xi)
    for w in range(N):
        eta = softmax(alphas[d])
        topic_distrib = np.random.multinomial(1, eta)
        z = np.where(topic_distrib == 1)[0][0]
        beta_mp = softmax(betas[d][z])
        word_distrib = np.random.multinomial(1, beta_mp)
        w = np.where(word_distrib == 1)[0][0]
        w_key = vocab[w]
        if w_key not in corpus[d]:
            corpus[d][w_key] = 0
        corpus[d][w_key] += 1

# %% [markdown]
# Normalise the generated corpus

# %%
from preprocessing import preprocess_corpus

count_max = 200
normalise = False
corpus = preprocess_corpus(corpus, vocab, threshold=count_max, normalise=normalise)

# %% [markdown]
# ### Run the inference

# %%
from dtm_alpha import DTM_alpha

iter_count = 2000
var_init = 1
var_basic = 0.1
var_prop = 0.15

dtm_alpha = DTM_alpha(K=K, iter_count=iter_count, var_init=var_init, var_basic=var_basic, var_prop=var_prop)
dtm_alpha.fit(corpus)

history_alpha = dtm_alpha.history_alpha
# Out:
# Iteration: 10
# Total alpha changes: 99
# Alpha update rate: 0.3960
# Iteration: 20
# Total alpha changes: 184
# Alpha update rate: 0.3680
# Iteration: 30
# Total alpha changes: 239
# Alpha update rate: 0.3187
# Iteration: 40
# Total alpha changes: 288
# Alpha update rate: 0.2880
# Iteration: 50
# Total alpha changes: 333
# Alpha update rate: 0.2664
# Iteration: 60
# Total alpha changes: 357
# Alpha update rate: 0.2380
# Iteration: 70
# Total alpha changes: 380
# Alpha update rate: 0.2171
# Iteration: 80
# Total alpha changes: 412
# Alpha update rate: 0.2060
# Iteration: 90
# Total alpha changes: 432
# Alpha update rate: 0.1920
# Iteration: 100
# Total alpha changes: 457
# Alpha update rate: 0.1828
# Iteration: 110
# Total alpha changes: 476
# Alpha update rate: 0.1731
# Iteration: 120
# Total alpha changes: 496
# Alpha update rate: 0.1653
# Iteration: 130
# Total alpha changes: 518
# Alpha update rate: 0.1594
# Iteration: 140
# Total alpha changes: 541
# Alpha update rate: 0.1546
# Iteration: 150
# Total alpha changes: 572
# Alpha update rate: 0.1525
# Iteration: 160
# Total alpha changes: 592
# Alpha update rate: 0.1480
# Iteration: 170
# Total alpha changes: 614
# Alpha update rate: 0.1445
# Iteration: 180
# Total alpha changes: 637
# Alpha update rate: 0.1416
# Iteration: 190
# Total alpha changes: 664
# Alpha update rate: 0.1398
# Iteration: 200
# Total alpha changes: 690
# Alpha update rate: 0.1380
# Iteration: 210
# Total alpha changes: 711
# Alpha update rate: 0.1354
# Iteration: 220
# Total alpha changes: 729
# Alpha update rate: 0.1325
# Iteration: 230
# Total alpha changes: 767
# Alpha update rate: 0.1334
# Iteration: 240
# Total alpha changes: 790
# Alpha update rate: 0.1317
# Iteration: 250
# Total alpha changes: 814
# Alpha update rate: 0.1302
# Iteration: 260
# Total alpha changes: 832
# Alpha update rate: 0.1280
# Iteration: 270
# Total alpha changes: 854
# Alpha update rate: 0.1265
# Iteration: 280
# Total alpha changes: 876
# Alpha update rate: 0.1251
# Iteration: 290
# Total alpha changes: 905
# Alpha update rate: 0.1248
# Iteration: 300
# Total alpha changes: 934
# Alpha update rate: 0.1245
# Iteration: 310
# Total alpha changes: 950
# Alpha update rate: 0.1226
# Iteration: 320
# Total alpha changes: 979
# Alpha update rate: 0.1224
# Iteration: 330
# Total alpha changes: 1004
# Alpha update rate: 0.1217
# Iteration: 340
# Total alpha changes: 1026
# Alpha update rate: 0.1207
# Iteration: 350
# Total alpha changes: 1048
# Alpha update rate: 0.1198
# Iteration: 360
# Total alpha changes: 1073
# Alpha update rate: 0.1192
# Iteration: 370
# Total alpha changes: 1103
# Alpha update rate: 0.1192
# Iteration: 380
# Total alpha changes: 1132
# Alpha update rate: 0.1192
# Iteration: 390
# Total alpha changes: 1146
# Alpha update rate: 0.1175
# Iteration: 400
# Total alpha changes: 1174
# Alpha update rate: 0.1174
# Iteration: 410
# Total alpha changes: 1199
# Alpha update rate: 0.1170
# Iteration: 420
# Total alpha changes: 1236
# Alpha update rate: 0.1177
# Iteration: 430
# Total alpha changes: 1258
# Alpha update rate: 0.1170
# Iteration: 440
# Total alpha changes: 1291
# Alpha update rate: 0.1174
# Iteration: 450
# Total alpha changes: 1319
# Alpha update rate: 0.1172
# Iteration: 460
# Total alpha changes: 1355
# Alpha update rate: 0.1178
# Iteration: 470
# Total alpha changes: 1384
# Alpha update rate: 0.1178
# Iteration: 480
# Total alpha changes: 1401
# Alpha update rate: 0.1168
# Iteration: 490
# Total alpha changes: 1429
# Alpha update rate: 0.1167
# Iteration: 500
# Total alpha changes: 1460
# Alpha update rate: 0.1168
# Iteration: 510
# Total alpha changes: 1482
# Alpha update rate: 0.1162
# Iteration: 520
# Total alpha changes: 1502
# Alpha update rate: 0.1155
# Iteration: 530
# Total alpha changes: 1528
# Alpha update rate: 0.1153
# Iteration: 540
# Total alpha changes: 1553
# Alpha update rate: 0.1150
# Iteration: 550
# Total alpha changes: 1574
# Alpha update rate: 0.1145
# Iteration: 560
# Total alpha changes: 1602
# Alpha update rate: 0.1144
# Iteration: 570
# Total alpha changes: 1626
# Alpha update rate: 0.1141
# Iteration: 580
# Total alpha changes: 1651
# Alpha update rate: 0.1139
# Iteration: 590
# Total alpha changes: 1668
# Alpha update rate: 0.1131
# Iteration: 600
# Total alpha changes: 1703
# Alpha update rate: 0.1135
# Iteration: 610
# Total alpha changes: 1735
# Alpha update rate: 0.1138
# Iteration: 620
# Total alpha changes: 1765
# Alpha update rate: 0.1139
# Iteration: 630
# Total alpha changes: 1794
# Alpha update rate: 0.1139
# Iteration: 640
# Total alpha changes: 1823
# Alpha update rate: 0.1139
# Iteration: 650
# Total alpha changes: 1848
# Alpha update rate: 0.1137
# Iteration: 660
# Total alpha changes: 1875
# Alpha update rate: 0.1136
# Iteration: 670
# Total alpha changes: 1890
# Alpha update rate: 0.1128
# Iteration: 680
# Total alpha changes: 1927
# Alpha update rate: 0.1134
# Iteration: 690
# Total alpha changes: 1962
# Alpha update rate: 0.1137
# Iteration: 700
# Total alpha changes: 1984
# Alpha update rate: 0.1134
# Iteration: 710
# Total alpha changes: 2012
# Alpha update rate: 0.1134
# Iteration: 720
# Total alpha changes: 2038
# Alpha update rate: 0.1132
# Iteration: 730
# Total alpha changes: 2070
# Alpha update rate: 0.1134
# Iteration: 740
# Total alpha changes: 2096
# Alpha update rate: 0.1133
# Iteration: 750
# Total alpha changes: 2124
# Alpha update rate: 0.1133
# Iteration: 760
# Total alpha changes: 2157
# Alpha update rate: 0.1135
# Iteration: 770
# Total alpha changes: 2183
# Alpha update rate: 0.1134
# Iteration: 780
# Total alpha changes: 2211
# Alpha update rate: 0.1134
# Iteration: 790
# Total alpha changes: 2250
# Alpha update rate: 0.1139
# Iteration: 800
# Total alpha changes: 2275
# Alpha update rate: 0.1138
# Iteration: 810
# Total alpha changes: 2301
# Alpha update rate: 0.1136
# Iteration: 820
# Total alpha changes: 2320
# Alpha update rate: 0.1132
# Iteration: 830
# Total alpha changes: 2343
# Alpha update rate: 0.1129
# Iteration: 840
# Total alpha changes: 2372
# Alpha update rate: 0.1130
# Iteration: 850
# Total alpha changes: 2403
# Alpha update rate: 0.1131
# Iteration: 860
# Total alpha changes: 2434
# Alpha update rate: 0.1132
# Iteration: 870
# Total alpha changes: 2463
# Alpha update rate: 0.1132
# Iteration: 880
# Total alpha changes: 2492
# Alpha update rate: 0.1133
# Iteration: 890
# Total alpha changes: 2519
# Alpha update rate: 0.1132
# Iteration: 900
# Total alpha changes: 2552
# Alpha update rate: 0.1134
# Iteration: 910
# Total alpha changes: 2575
# Alpha update rate: 0.1132
# Iteration: 920
# Total alpha changes: 2604
# Alpha update rate: 0.1132
# Iteration: 930
# Total alpha changes: 2628
# Alpha update rate: 0.1130
# Iteration: 940
# Total alpha changes: 2659
# Alpha update rate: 0.1131
# Iteration: 950
# Total alpha changes: 2686
# Alpha update rate: 0.1131
# Iteration: 960
# Total alpha changes: 2703
# Alpha update rate: 0.1126
# Iteration: 970
# Total alpha changes: 2741
# Alpha update rate: 0.1130
# Iteration: 980
# Total alpha changes: 2774
# Alpha update rate: 0.1132
# Iteration: 990
# Total alpha changes: 2805
# Alpha update rate: 0.1133
# Iteration: 1000
# Total alpha changes: 2831
# Alpha update rate: 0.1132
# Iteration: 1010
# Total alpha changes: 2846
# Alpha update rate: 0.1127
# Iteration: 1020
# Total alpha changes: 2878
# Alpha update rate: 0.1129
# Iteration: 1030
# Total alpha changes: 2910
# Alpha update rate: 0.1130
# Iteration: 1040
# Total alpha changes: 2936
# Alpha update rate: 0.1129
# Iteration: 1050
# Total alpha changes: 2957
# Alpha update rate: 0.1126
# Iteration: 1060
# Total alpha changes: 2987
# Alpha update rate: 0.1127
# Iteration: 1070
# Total alpha changes: 3021
# Alpha update rate: 0.1129
# Iteration: 1080
# Total alpha changes: 3046
# Alpha update rate: 0.1128
# Iteration: 1090
# Total alpha changes: 3080
# Alpha update rate: 0.1130
# Iteration: 1100
# Total alpha changes: 3107
# Alpha update rate: 0.1130
# Iteration: 1110
# Total alpha changes: 3131
# Alpha update rate: 0.1128
# Iteration: 1120
# Total alpha changes: 3170
# Alpha update rate: 0.1132
# Iteration: 1130
# Total alpha changes: 3192
# Alpha update rate: 0.1130
# Iteration: 1140
# Total alpha changes: 3225
# Alpha update rate: 0.1132
# Iteration: 1150
# Total alpha changes: 3250
# Alpha update rate: 0.1130
# Iteration: 1160
# Total alpha changes: 3295
# Alpha update rate: 0.1136
# Iteration: 1170
# Total alpha changes: 3333
# Alpha update rate: 0.1139
# Iteration: 1180
# Total alpha changes: 3367
# Alpha update rate: 0.1141
# Iteration: 1190
# Total alpha changes: 3394
# Alpha update rate: 0.1141
# Iteration: 1200
# Total alpha changes: 3417
# Alpha update rate: 0.1139
# Iteration: 1210
# Total alpha changes: 3449
# Alpha update rate: 0.1140
# Iteration: 1220
# Total alpha changes: 3470
# Alpha update rate: 0.1138
# Iteration: 1230
# Total alpha changes: 3505
# Alpha update rate: 0.1140
# Iteration: 1240
# Total alpha changes: 3528
# Alpha update rate: 0.1138
# Iteration: 1250
# Total alpha changes: 3555
# Alpha update rate: 0.1138
# Iteration: 1260
# Total alpha changes: 3583
# Alpha update rate: 0.1137
# Iteration: 1270
# Total alpha changes: 3613
# Alpha update rate: 0.1138
# Iteration: 1280
# Total alpha changes: 3640
# Alpha update rate: 0.1138
# Iteration: 1290
# Total alpha changes: 3663
# Alpha update rate: 0.1136
# Iteration: 1300
# Total alpha changes: 3695
# Alpha update rate: 0.1137
# Iteration: 1310
# Total alpha changes: 3722
# Alpha update rate: 0.1136
# Iteration: 1320
# Total alpha changes: 3751
# Alpha update rate: 0.1137
# Iteration: 1330
# Total alpha changes: 3780
# Alpha update rate: 0.1137
# Iteration: 1340
# Total alpha changes: 3800
# Alpha update rate: 0.1134
# Iteration: 1350
# Total alpha changes: 3835
# Alpha update rate: 0.1136
# Iteration: 1360
# Total alpha changes: 3866
# Alpha update rate: 0.1137
# Iteration: 1370
# Total alpha changes: 3904
# Alpha update rate: 0.1140
# Iteration: 1380
# Total alpha changes: 3935
# Alpha update rate: 0.1141
# Iteration: 1390
# Total alpha changes: 3963
# Alpha update rate: 0.1140
# Iteration: 1400
# Total alpha changes: 3991
# Alpha update rate: 0.1140
# Iteration: 1410
# Total alpha changes: 4019
# Alpha update rate: 0.1140
# Iteration: 1420
# Total alpha changes: 4046
# Alpha update rate: 0.1140
# Iteration: 1430
# Total alpha changes: 4069
# Alpha update rate: 0.1138
# Iteration: 1440
# Total alpha changes: 4094
# Alpha update rate: 0.1137
# Iteration: 1450
# Total alpha changes: 4127
# Alpha update rate: 0.1138
# Iteration: 1460
# Total alpha changes: 4155
# Alpha update rate: 0.1138
# Iteration: 1470
# Total alpha changes: 4190
# Alpha update rate: 0.1140
# Iteration: 1480
# Total alpha changes: 4231
# Alpha update rate: 0.1144
# Iteration: 1490
# Total alpha changes: 4268
# Alpha update rate: 0.1146
# Iteration: 1500
# Total alpha changes: 4294
# Alpha update rate: 0.1145
# Iteration: 1510
# Total alpha changes: 4317
# Alpha update rate: 0.1144
# Iteration: 1520
# Total alpha changes: 4362
# Alpha update rate: 0.1148
# Iteration: 1530
# Total alpha changes: 4393
# Alpha update rate: 0.1148
# Iteration: 1540
# Total alpha changes: 4422
# Alpha update rate: 0.1149
# Iteration: 1550
# Total alpha changes: 4450
# Alpha update rate: 0.1148
# Iteration: 1560
# Total alpha changes: 4474
# Alpha update rate: 0.1147
# Iteration: 1570
# Total alpha changes: 4512
# Alpha update rate: 0.1150
# Iteration: 1580
# Total alpha changes: 4546
# Alpha update rate: 0.1151
# Iteration: 1590
# Total alpha changes: 4570
# Alpha update rate: 0.1150
# Iteration: 1600
# Total alpha changes: 4590
# Alpha update rate: 0.1148
# Iteration: 1610
# Total alpha changes: 4620
# Alpha update rate: 0.1148
# Iteration: 1620
# Total alpha changes: 4647
# Alpha update rate: 0.1147
# Iteration: 1630
# Total alpha changes: 4666
# Alpha update rate: 0.1145
# Iteration: 1640
# Total alpha changes: 4703
# Alpha update rate: 0.1147
# Iteration: 1650
# Total alpha changes: 4732
# Alpha update rate: 0.1147
# Iteration: 1660
# Total alpha changes: 4771
# Alpha update rate: 0.1150
# Iteration: 1670
# Total alpha changes: 4794
# Alpha update rate: 0.1148
# Iteration: 1680
# Total alpha changes: 4825
# Alpha update rate: 0.1149
# Iteration: 1690
# Total alpha changes: 4856
# Alpha update rate: 0.1149
# Iteration: 1700
# Total alpha changes: 4877
# Alpha update rate: 0.1148
# Iteration: 1710
# Total alpha changes: 4897
# Alpha update rate: 0.1145
# Iteration: 1720
# Total alpha changes: 4924
# Alpha update rate: 0.1145
# Iteration: 1730
# Total alpha changes: 4957
# Alpha update rate: 0.1146
# Iteration: 1740
# Total alpha changes: 4991
# Alpha update rate: 0.1147
# Iteration: 1750
# Total alpha changes: 5010
# Alpha update rate: 0.1145
# Iteration: 1760
# Total alpha changes: 5038
# Alpha update rate: 0.1145
# Iteration: 1770
# Total alpha changes: 5067
# Alpha update rate: 0.1145
# Iteration: 1780
# Total alpha changes: 5102
# Alpha update rate: 0.1147
# Iteration: 1790
# Total alpha changes: 5139
# Alpha update rate: 0.1148
# Iteration: 1800
# Total alpha changes: 5162
# Alpha update rate: 0.1147
# Iteration: 1810
# Total alpha changes: 5200
# Alpha update rate: 0.1149
# Iteration: 1820
# Total alpha changes: 5235
# Alpha update rate: 0.1151
# Iteration: 1830
# Total alpha changes: 5266
# Alpha update rate: 0.1151
# Iteration: 1840
# Total alpha changes: 5295
# Alpha update rate: 0.1151
# Iteration: 1850
# Total alpha changes: 5325
# Alpha update rate: 0.1151
# Iteration: 1860
# Total alpha changes: 5350
# Alpha update rate: 0.1151
# Iteration: 1870
# Total alpha changes: 5374
# Alpha update rate: 0.1150
# Iteration: 1880
# Total alpha changes: 5400
# Alpha update rate: 0.1149
# Iteration: 1890
# Total alpha changes: 5438
# Alpha update rate: 0.1151
# Iteration: 1900
# Total alpha changes: 5468
# Alpha update rate: 0.1151
# Iteration: 1910
# Total alpha changes: 5496
# Alpha update rate: 0.1151
# Iteration: 1920
# Total alpha changes: 5525
# Alpha update rate: 0.1151
# Iteration: 1930
# Total alpha changes: 5559
# Alpha update rate: 0.1152
# Iteration: 1940
# Total alpha changes: 5589
# Alpha update rate: 0.1152
# Iteration: 1950
# Total alpha changes: 5615
# Alpha update rate: 0.1152
# Iteration: 1960
# Total alpha changes: 5639
# Alpha update rate: 0.1151
# Iteration: 1970
# Total alpha changes: 5662
# Alpha update rate: 0.1150
# Iteration: 1980
# Total alpha changes: 5694
# Alpha update rate: 0.1150
# Iteration: 1990
# Total alpha changes: 5726
# Alpha update rate: 0.1151

# %% [markdown]
# #### Save the corpora

# %%
string_var = '_%.0E' % var_prop # Fix the naming for 0.15 var_prop

alphas.dump('alphas_init_' + str(iter_count) + string_var + '.pkl')
history_alpha.dump('history_alpha_' + str(iter_count) + string_var + '.pkl')

# %% [markdown]
# #### Load corpora

# %%
iter_count = 2000
var_prop = 0.3
string_var = '_%.0E' % var_prop

alphas = pd.read_pickle('alphas_init_' + str(iter_count) + string_var + '.pkl')
history_alpha = pd.read_pickle('history_alpha_' + str(iter_count) + string_var + '.pkl')

# %% [markdown]
# ### Observing the results

# %% [markdown]
# #### Plot the updated alphas in 3D

# %%
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly.graph_objs as go

n_alphas = history_alpha.shape[2]
list_alphas = []
for i in range(n_alphas):
    alpha = dict(z = history_alpha[:, :, i], type='surface')
    list_alphas.append(alpha)
fig = go.Figure(data=list_alphas)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perdaugmazas/241.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# #### Plot the alphas used at the corpus generation

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

ts = np.linspace(0, T-1, num=T)
plt.plot(ts, alphas, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f22ef253f10>,
#  <matplotlib.lines.Line2D at 0x7f22ef261150>]

# %% [markdown]
# #### Plot the last updated alphas

# %%
alphas_updated = history_alpha[iter_count-1]
plt.plot(ts, alphas_updated, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f22eeef1090>,
#  <matplotlib.lines.Line2D at 0x7f22eeef1290>]

# %% [markdown]
# #### Plot the thetas used at the corpus generation

# %%
thetas = np.zeros(shape=alphas.shape)
for t, alpha_t in enumerate(alphas):
    thetas[t] = softmax(alpha_t)
plt.plot(ts, thetas, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f22ef0ce1d0>,
#  <matplotlib.lines.Line2D at 0x7f22ef0ce3d0>]

# %% [markdown]
# #### Plot the updated thetas

# %%
# alphas_updated = history_alpha[99]
thetas_updated = np.zeros(shape=alphas_updated.shape)
for t, alpha_t in enumerate(alphas_updated):
    thetas_updated[t] = softmax(alpha_t)
plt.plot(ts, thetas_updated, linewidth=2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f22ef009710>,
#  <matplotlib.lines.Line2D at 0x7f22ef009910>]
