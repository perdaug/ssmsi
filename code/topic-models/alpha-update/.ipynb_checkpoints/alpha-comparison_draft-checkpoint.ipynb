# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
np.set_printoptions(threshold=np.nan)
import matplotlib.pyplot as plt
# %matplotlib inline

def softmax(arr):
    return np.exp(arr) / np.sum(np.exp(arr))

## Corpus parameters
K = 2
xi = 1000 # Approximate number of words
T = 20
linspace_t = np.linspace(0, T-1, num=T)
V = 10

## Random Betas
# prior_dirichlet = np.repeat(1./V, V)
# beta = np.random.dirichlet(prior_dirichlet, K)

beta = np.array([[0, 0, 0, 0.3, 0.7, 0, 0, 0, 0, 0], [0, 0, 0.2, 0, 0, 0, 0, 0.3, 0.3, 0.2]])

alphas = np.zeros((T, K))
linspace_4pi = np.linspace(0, 4*np.pi, num=T)
alphas[:,0] = np.sin(linspace_4pi) 
alphas[:,1] = np.cos(linspace_4pi)

# %% [markdown]
# ### Generate a corpus

# %%
import string

## Initialise the vocabulary
vocab = []
for w in range(V):
    vocab.append(string.ascii_lowercase[w])

corpus = {}
for d in range(T):
    corpus[d] = {}
    N = np.random.poisson(xi)
    for w in range(N):
        theta = softmax(alphas[d])
#         topic_distrib = np.random.multinomial(1, theta)
        topic_distrib = np.random.multinomial(1, alphas[d])
        z = np.where(topic_distrib == 1)[0][0]
        word_distrib = np.random.multinomial(1, beta[z])
        w = np.where(word_distrib == 1)[0][0]
        w_key = vocab[w]
        if w_key not in corpus[d]:
            corpus[d][w_key] = 0
        corpus[d][w_key] += 1

from preprocessing import preprocess_corpus
count_max = 200.
normalise = False
corpus = preprocess_corpus(corpus, vocab, threshold=count_max, normalise=normalise)
# corpus.dump('corpus_test.pkl')

# %% [markdown]
# ### Import the corpus

# %%
corpus = pd.read_pickle('corpus_test.pkl')

# %% [markdown]
# ### Visualise the betas

# %%
linspace_V = np.linspace(0, V-1, num=V)

plt.figure(1)
plt.bar(linspace_V, beta[0], label='k=0')
plt.bar(linspace_V, beta[1], label='k=1')
plt.xticks(np.arange(0, 10, 1.0))
plt.legend(loc=1)
plt.xlabel('V')
plt.ylabel(r'$\beta$')
plt.savefig('betas.png')

# %% [markdown]
# ### Visualise the thetas

# %%
from matplotlib.ticker import MaxNLocator
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

alphas_softmax = np.zeros(shape=alphas.shape)
for t, alpha_t in enumerate(alphas):
    alphas_softmax[t] = softmax(alpha_t)
alphas_softmax = alphas_softmax.T
labels = ['k=0', 'k=1']
for y_arr, label in zip(alphas_softmax, labels):
    plt.plot(linspace_t, y_arr, label=label)

plt.xlabel('t')
plt.ylabel(r'softmax($\alpha$)')
plt.legend(loc=1)
plt.savefig('mu.png')

# %% [markdown]
# ### Fit

# %%
from dtm_alpha import DTM_Alpha

n_it = 2000
var_init = 0.1
var_basic = 0.1
var_prop = 1
autoreg = True
dtm_alpha = DTM_Alpha(K=K, sigma_0_sq=var_init, sigma_sq=var_basic, 
        delta_sq=var_prop, autoreg=autoreg)
dtm_alpha.beta = beta
dtm_alpha.fit(corpus=corpus, n_it=n_it)
# Out:
# Iteration: 10
# Total alpha changes: 35
# Alpha update rate: 0.0875
# Iteration: 20
# Total alpha changes: 87
# Alpha update rate: 0.1087
# Iteration: 30
# Total alpha changes: 139
# Alpha update rate: 0.1158
# Iteration: 40
# Total alpha changes: 170
# Alpha update rate: 0.1062
# Iteration: 50
# Total alpha changes: 218
# Alpha update rate: 0.1090
# Iteration: 60
# Total alpha changes: 268
# Alpha update rate: 0.1117
# Iteration: 70
# Total alpha changes: 322
# Alpha update rate: 0.1150
# Iteration: 80
# Total alpha changes: 384
# Alpha update rate: 0.1200
# Iteration: 90
# Total alpha changes: 434
# Alpha update rate: 0.1206
# Iteration: 100
# Total alpha changes: 503
# Alpha update rate: 0.1258
# Iteration: 110
# Total alpha changes: 552
# Alpha update rate: 0.1255
# Iteration: 120
# Total alpha changes: 606
# Alpha update rate: 0.1263
# Iteration: 130
# Total alpha changes: 654
# Alpha update rate: 0.1258
# Iteration: 140
# Total alpha changes: 704
# Alpha update rate: 0.1257
# Iteration: 150
# Total alpha changes: 755
# Alpha update rate: 0.1258
# Iteration: 160
# Total alpha changes: 796
# Alpha update rate: 0.1244
# Iteration: 170
# Total alpha changes: 853
# Alpha update rate: 0.1254
# Iteration: 180
# Total alpha changes: 913
# Alpha update rate: 0.1268
# Iteration: 190
# Total alpha changes: 955
# Alpha update rate: 0.1257
# Iteration: 200
# Total alpha changes: 1009
# Alpha update rate: 0.1261
# Iteration: 210
# Total alpha changes: 1059
# Alpha update rate: 0.1261
# Iteration: 220
# Total alpha changes: 1113
# Alpha update rate: 0.1265
# Iteration: 230
# Total alpha changes: 1156
# Alpha update rate: 0.1257
# Iteration: 240
# Total alpha changes: 1216
# Alpha update rate: 0.1267
# Iteration: 250
# Total alpha changes: 1269
# Alpha update rate: 0.1269
# Iteration: 260
# Total alpha changes: 1326
# Alpha update rate: 0.1275
# Iteration: 270
# Total alpha changes: 1376
# Alpha update rate: 0.1274
# Iteration: 280
# Total alpha changes: 1428
# Alpha update rate: 0.1275
# Iteration: 290
# Total alpha changes: 1484
# Alpha update rate: 0.1279
# Iteration: 300
# Total alpha changes: 1529
# Alpha update rate: 0.1274
# Iteration: 310
# Total alpha changes: 1588
# Alpha update rate: 0.1281
# Iteration: 320
# Total alpha changes: 1647
# Alpha update rate: 0.1287
# Iteration: 330
# Total alpha changes: 1699
# Alpha update rate: 0.1287
# Iteration: 340
# Total alpha changes: 1753
# Alpha update rate: 0.1289
# Iteration: 350
# Total alpha changes: 1792
# Alpha update rate: 0.1280
# Iteration: 360
# Total alpha changes: 1843
# Alpha update rate: 0.1280
# Iteration: 370
# Total alpha changes: 1894
# Alpha update rate: 0.1280
# Iteration: 380
# Total alpha changes: 1946
# Alpha update rate: 0.1280
# Iteration: 390
# Total alpha changes: 1999
# Alpha update rate: 0.1281
# Iteration: 400
# Total alpha changes: 2049
# Alpha update rate: 0.1281
# Iteration: 410
# Total alpha changes: 2103
# Alpha update rate: 0.1282
# Iteration: 420
# Total alpha changes: 2157
# Alpha update rate: 0.1284
# Iteration: 430
# Total alpha changes: 2207
# Alpha update rate: 0.1283
# Iteration: 440
# Total alpha changes: 2268
# Alpha update rate: 0.1289
# Iteration: 450
# Total alpha changes: 2327
# Alpha update rate: 0.1293
# Iteration: 460
# Total alpha changes: 2384
# Alpha update rate: 0.1296
# Iteration: 470
# Total alpha changes: 2431
# Alpha update rate: 0.1293
# Iteration: 480
# Total alpha changes: 2487
# Alpha update rate: 0.1295
# Iteration: 490
# Total alpha changes: 2546
# Alpha update rate: 0.1299
# Iteration: 500
# Total alpha changes: 2598
# Alpha update rate: 0.1299
# Iteration: 510
# Total alpha changes: 2649
# Alpha update rate: 0.1299
# Iteration: 520
# Total alpha changes: 2705
# Alpha update rate: 0.1300
# Iteration: 530
# Total alpha changes: 2765
# Alpha update rate: 0.1304
# Iteration: 540
# Total alpha changes: 2816
# Alpha update rate: 0.1304
# Iteration: 550
# Total alpha changes: 2875
# Alpha update rate: 0.1307
# Iteration: 560
# Total alpha changes: 2938
# Alpha update rate: 0.1312
# Iteration: 570
# Total alpha changes: 3001
# Alpha update rate: 0.1316
# Iteration: 580
# Total alpha changes: 3044
# Alpha update rate: 0.1312
# Iteration: 590
# Total alpha changes: 3093
# Alpha update rate: 0.1311
# Iteration: 600
# Total alpha changes: 3151
# Alpha update rate: 0.1313
# Iteration: 610
# Total alpha changes: 3207
# Alpha update rate: 0.1314
# Iteration: 620
# Total alpha changes: 3261
# Alpha update rate: 0.1315
# Iteration: 630
# Total alpha changes: 3332
# Alpha update rate: 0.1322
# Iteration: 640
# Total alpha changes: 3388
# Alpha update rate: 0.1323
# Iteration: 650
# Total alpha changes: 3448
# Alpha update rate: 0.1326
# Iteration: 660
# Total alpha changes: 3503
# Alpha update rate: 0.1327
# Iteration: 670
# Total alpha changes: 3569
# Alpha update rate: 0.1332
# Iteration: 680
# Total alpha changes: 3641
# Alpha update rate: 0.1339
# Iteration: 690
# Total alpha changes: 3697
# Alpha update rate: 0.1339
# Iteration: 700
# Total alpha changes: 3751
# Alpha update rate: 0.1340
# Iteration: 710
# Total alpha changes: 3809
# Alpha update rate: 0.1341
# Iteration: 720
# Total alpha changes: 3873
# Alpha update rate: 0.1345
# Iteration: 730
# Total alpha changes: 3914
# Alpha update rate: 0.1340
# Iteration: 740
# Total alpha changes: 3967
# Alpha update rate: 0.1340
# Iteration: 750
# Total alpha changes: 4019
# Alpha update rate: 0.1340
# Iteration: 760
# Total alpha changes: 4075
# Alpha update rate: 0.1340
# Iteration: 770
# Total alpha changes: 4138
# Alpha update rate: 0.1344
# Iteration: 780
# Total alpha changes: 4203
# Alpha update rate: 0.1347
# Iteration: 790
# Total alpha changes: 4269
# Alpha update rate: 0.1351
# Iteration: 800
# Total alpha changes: 4328
# Alpha update rate: 0.1353
# Iteration: 810
# Total alpha changes: 4382
# Alpha update rate: 0.1352
# Iteration: 820
# Total alpha changes: 4439
# Alpha update rate: 0.1353
# Iteration: 830
# Total alpha changes: 4503
# Alpha update rate: 0.1356
# Iteration: 840
# Total alpha changes: 4563
# Alpha update rate: 0.1358
# Iteration: 850
# Total alpha changes: 4629
# Alpha update rate: 0.1361
# Iteration: 860
# Total alpha changes: 4689
# Alpha update rate: 0.1363
# Iteration: 870
# Total alpha changes: 4755
# Alpha update rate: 0.1366
# Iteration: 880
# Total alpha changes: 4826
# Alpha update rate: 0.1371
# Iteration: 890
# Total alpha changes: 4879
# Alpha update rate: 0.1371
# Iteration: 900
# Total alpha changes: 4930
# Alpha update rate: 0.1369
# Iteration: 910
# Total alpha changes: 4983
# Alpha update rate: 0.1369
# Iteration: 920
# Total alpha changes: 5043
# Alpha update rate: 0.1370
# Iteration: 930
# Total alpha changes: 5104
# Alpha update rate: 0.1372
# Iteration: 940
# Total alpha changes: 5157
# Alpha update rate: 0.1372
# Iteration: 950
# Total alpha changes: 5230
# Alpha update rate: 0.1376
# Iteration: 960
# Total alpha changes: 5286
# Alpha update rate: 0.1377
# Iteration: 970
# Total alpha changes: 5335
# Alpha update rate: 0.1375
# Iteration: 980
# Total alpha changes: 5385
# Alpha update rate: 0.1374
# Iteration: 990
# Total alpha changes: 5437
# Alpha update rate: 0.1373
# Iteration: 1000
# Total alpha changes: 5493
# Alpha update rate: 0.1373
# Iteration: 1010
# Total alpha changes: 5546
# Alpha update rate: 0.1373
# Iteration: 1020
# Total alpha changes: 5601
# Alpha update rate: 0.1373
# Iteration: 1030
# Total alpha changes: 5649
# Alpha update rate: 0.1371
# Iteration: 1040
# Total alpha changes: 5694
# Alpha update rate: 0.1369
# Iteration: 1050
# Total alpha changes: 5750
# Alpha update rate: 0.1369
# Iteration: 1060
# Total alpha changes: 5809
# Alpha update rate: 0.1370
# Iteration: 1070
# Total alpha changes: 5869
# Alpha update rate: 0.1371
# Iteration: 1080
# Total alpha changes: 5921
# Alpha update rate: 0.1371
# Iteration: 1090
# Total alpha changes: 5966
# Alpha update rate: 0.1368
# Iteration: 1100
# Total alpha changes: 6019
# Alpha update rate: 0.1368
# Iteration: 1110
# Total alpha changes: 6071
# Alpha update rate: 0.1367
# Iteration: 1120
# Total alpha changes: 6136
# Alpha update rate: 0.1370
# Iteration: 1130
# Total alpha changes: 6193
# Alpha update rate: 0.1370
# Iteration: 1140
# Total alpha changes: 6254
# Alpha update rate: 0.1371
# Iteration: 1150
# Total alpha changes: 6300
# Alpha update rate: 0.1370
# Iteration: 1160
# Total alpha changes: 6351
# Alpha update rate: 0.1369
# Iteration: 1170
# Total alpha changes: 6417
# Alpha update rate: 0.1371
# Iteration: 1180
# Total alpha changes: 6464
# Alpha update rate: 0.1369
# Iteration: 1190
# Total alpha changes: 6510
# Alpha update rate: 0.1368
# Iteration: 1200
# Total alpha changes: 6574
# Alpha update rate: 0.1370
# Iteration: 1210
# Total alpha changes: 6636
# Alpha update rate: 0.1371
# Iteration: 1220
# Total alpha changes: 6707
# Alpha update rate: 0.1374
# Iteration: 1230
# Total alpha changes: 6757
# Alpha update rate: 0.1373
# Iteration: 1240
# Total alpha changes: 6818
# Alpha update rate: 0.1375
# Iteration: 1250
# Total alpha changes: 6882
# Alpha update rate: 0.1376
# Iteration: 1260
# Total alpha changes: 6943
# Alpha update rate: 0.1378
# Iteration: 1270
# Total alpha changes: 7002
# Alpha update rate: 0.1378
# Iteration: 1280
# Total alpha changes: 7060
# Alpha update rate: 0.1379
# Iteration: 1290
# Total alpha changes: 7126
# Alpha update rate: 0.1381
# Iteration: 1300
# Total alpha changes: 7184
# Alpha update rate: 0.1382
# Iteration: 1310
# Total alpha changes: 7242
# Alpha update rate: 0.1382
# Iteration: 1320
# Total alpha changes: 7310
# Alpha update rate: 0.1384
# Iteration: 1330
# Total alpha changes: 7363
# Alpha update rate: 0.1384
# Iteration: 1340
# Total alpha changes: 7419
# Alpha update rate: 0.1384
# Iteration: 1350
# Total alpha changes: 7488
# Alpha update rate: 0.1387
# Iteration: 1360
# Total alpha changes: 7561
# Alpha update rate: 0.1390
# Iteration: 1370
# Total alpha changes: 7608
# Alpha update rate: 0.1388
# Iteration: 1380
# Total alpha changes: 7656
# Alpha update rate: 0.1387
# Iteration: 1390
# Total alpha changes: 7709
# Alpha update rate: 0.1387
# Iteration: 1400
# Total alpha changes: 7759
# Alpha update rate: 0.1386
# Iteration: 1410
# Total alpha changes: 7820
# Alpha update rate: 0.1387
# Iteration: 1420
# Total alpha changes: 7896
# Alpha update rate: 0.1390
# Iteration: 1430
# Total alpha changes: 7970
# Alpha update rate: 0.1393
# Iteration: 1440
# Total alpha changes: 8042
# Alpha update rate: 0.1396
# Iteration: 1450
# Total alpha changes: 8106
# Alpha update rate: 0.1398
# Iteration: 1460
# Total alpha changes: 8175
# Alpha update rate: 0.1400
# Iteration: 1470
# Total alpha changes: 8229
# Alpha update rate: 0.1399
# Iteration: 1480
# Total alpha changes: 8277
# Alpha update rate: 0.1398
# Iteration: 1490
# Total alpha changes: 8335
# Alpha update rate: 0.1398
# Iteration: 1500
# Total alpha changes: 8387
# Alpha update rate: 0.1398
# Iteration: 1510
# Total alpha changes: 8447
# Alpha update rate: 0.1399
# Iteration: 1520
# Total alpha changes: 8496
# Alpha update rate: 0.1397
# Iteration: 1530
# Total alpha changes: 8551
# Alpha update rate: 0.1397
# Iteration: 1540
# Total alpha changes: 8610
# Alpha update rate: 0.1398
# Iteration: 1550
# Total alpha changes: 8672
# Alpha update rate: 0.1399
# Iteration: 1560
# Total alpha changes: 8734
# Alpha update rate: 0.1400
# Iteration: 1570
# Total alpha changes: 8792
# Alpha update rate: 0.1400
# Iteration: 1580
# Total alpha changes: 8854
# Alpha update rate: 0.1401
# Iteration: 1590
# Total alpha changes: 8902
# Alpha update rate: 0.1400
# Iteration: 1600
# Total alpha changes: 8960
# Alpha update rate: 0.1400
# Iteration: 1610
# Total alpha changes: 9020
# Alpha update rate: 0.1401
# Iteration: 1620
# Total alpha changes: 9089
# Alpha update rate: 0.1403
# Iteration: 1630
# Total alpha changes: 9132
# Alpha update rate: 0.1401
# Iteration: 1640
# Total alpha changes: 9189
# Alpha update rate: 0.1401
# Iteration: 1650
# Total alpha changes: 9243
# Alpha update rate: 0.1400
# Iteration: 1660
# Total alpha changes: 9314
# Alpha update rate: 0.1403
# Iteration: 1670
# Total alpha changes: 9375
# Alpha update rate: 0.1403
# Iteration: 1680
# Total alpha changes: 9439
# Alpha update rate: 0.1405
# Iteration: 1690
# Total alpha changes: 9495
# Alpha update rate: 0.1405
# Iteration: 1700
# Total alpha changes: 9555
# Alpha update rate: 0.1405
# Iteration: 1710
# Total alpha changes: 9604
# Alpha update rate: 0.1404
# Iteration: 1720
# Total alpha changes: 9670
# Alpha update rate: 0.1406
# Iteration: 1730
# Total alpha changes: 9726
# Alpha update rate: 0.1405
# Iteration: 1740
# Total alpha changes: 9781
# Alpha update rate: 0.1405
# Iteration: 1750
# Total alpha changes: 9844
# Alpha update rate: 0.1406
# Iteration: 1760
# Total alpha changes: 9892
# Alpha update rate: 0.1405
# Iteration: 1770
# Total alpha changes: 9948
# Alpha update rate: 0.1405
# Iteration: 1780
# Total alpha changes: 10013
# Alpha update rate: 0.1406
# Iteration: 1790
# Total alpha changes: 10068
# Alpha update rate: 0.1406
# Iteration: 1800
# Total alpha changes: 10128
# Alpha update rate: 0.1407
# Iteration: 1810
# Total alpha changes: 10197
# Alpha update rate: 0.1408
# Iteration: 1820
# Total alpha changes: 10246
# Alpha update rate: 0.1407
# Iteration: 1830
# Total alpha changes: 10308
# Alpha update rate: 0.1408
# Iteration: 1840
# Total alpha changes: 10367
# Alpha update rate: 0.1409
# Iteration: 1850
# Total alpha changes: 10417
# Alpha update rate: 0.1408
# Iteration: 1860
# Total alpha changes: 10467
# Alpha update rate: 0.1407
# Iteration: 1870
# Total alpha changes: 10510
# Alpha update rate: 0.1405
# Iteration: 1880
# Total alpha changes: 10566
# Alpha update rate: 0.1405
# Iteration: 1890
# Total alpha changes: 10616
# Alpha update rate: 0.1404
# Iteration: 1900
# Total alpha changes: 10666
# Alpha update rate: 0.1403
# Iteration: 1910
# Total alpha changes: 10734
# Alpha update rate: 0.1405
# Iteration: 1920
# Total alpha changes: 10789
# Alpha update rate: 0.1405
# Iteration: 1930
# Total alpha changes: 10843
# Alpha update rate: 0.1405
# Iteration: 1940
# Total alpha changes: 10913
# Alpha update rate: 0.1406
# Iteration: 1950
# Total alpha changes: 10959
# Alpha update rate: 0.1405
# Iteration: 1960
# Total alpha changes: 11012
# Alpha update rate: 0.1405
# Iteration: 1970
# Total alpha changes: 11092
# Alpha update rate: 0.1408
# Iteration: 1980
# Total alpha changes: 11148
# Alpha update rate: 0.1408
# Iteration: 1990
# Total alpha changes: 11219
# Alpha update rate: 0.1409

# %% [markdown]
# ### Print and dump

# %%
# Calculate the softmax
history_alpha = dtm_alpha.hist_alpha
labels = []
curves = []
settings = []
colours = ['orange', 'b']
for it in xrange(0, 2):
    idx = n_it - int(it * n_it/2)
    alphas_last_proposed = history_alpha[idx-1]
    alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
    for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
        alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)
    alphas_softmax_last_proposed = alphas_softmax_last_proposed.T
    for id_label, alpha in enumerate(alphas_softmax_last_proposed):
        curves.append(alpha)
        settings.append((colours[id_label],1-(it*0.5)))
        labels.append('k=%d, it=%d' % (id_label, idx))

# Plot the figure
from matplotlib.ticker import MaxNLocator
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

for y_arr, label, setting in zip(curves, labels, settings):
    plt.plot(linspace_t, y_arr, label=label, color=setting[0], alpha=setting[1])
title_fig = r'$\sigma_0^2=%.2f,\quad \sigma^2=%.4f,\quad \delta^2=%.1f$' \
        % (var_init, var_basic, var_prop)
plt.title(title_fig)
plt.legend(loc=1)
plt.xlabel('t')
plt.ylabel(r'$\theta$')

# Save the plot and the model
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it, str(autoreg))
plt.savefig('results/' + name_model_out + '.png', dpi=300)
vars_dtm = vars(dtm_alpha)
with open('models/' + name_model_out + '.pkl', 'wb') as f:
        pkl.dump(vars_dtm, f)

# %% [markdown]
# ### Load, fit, and dump

# %%
# from dtm_alpha import DTM_Alpha

n_it = 500
n_it_add = 500
var_init = 1
var_basic = 0.001
var_prop = 1
autoreg=True
name_model_in = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it, str(autoreg))
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it + n_it_add, str(autoreg))

dtm_alpha = DTM_Alpha()
dtm_alpha.load_fit('models/' + name_model_in + '.pkl', n_it=n_it_add)

history_alpha = dtm_alpha.hist_alpha
alphas_last_proposed = history_alpha[n_it-1]
alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
    alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)

plt.plot(linspace_t, alphas_softmax_last_proposed, linewidth=2)

## Save the results
# plt.savefig('results/' + name_model_out + '.png')
# vars_dtm = vars(dtm_alpha)
# with open('models/' + name_model_out + '.pkl', 'wb') as f:
#         pkl.dump(vars_dtm, f)
# Out:
# Iteration: 500
# Total alpha changes: 2796
# Alpha update rate: 0.1398
# Iteration: 510
# Total alpha changes: 2841
# Alpha update rate: 0.1393
# Iteration: 520
# Total alpha changes: 2903
# Alpha update rate: 0.1396
# Iteration: 530
# Total alpha changes: 2957
# Alpha update rate: 0.1395
# Iteration: 540
# Total alpha changes: 3022
# Alpha update rate: 0.1399
# Iteration: 550
# Total alpha changes: 3087
# Alpha update rate: 0.1403
# Iteration: 560
# Total alpha changes: 3138
# Alpha update rate: 0.1401
# Iteration: 570
# Total alpha changes: 3186
# Alpha update rate: 0.1397
# Iteration: 580
# Total alpha changes: 3242
# Alpha update rate: 0.1397
# Iteration: 590
# Total alpha changes: 3297
# Alpha update rate: 0.1397
# Iteration: 600
# Total alpha changes: 3362
# Alpha update rate: 0.1401
# Iteration: 610
# Total alpha changes: 3416
# Alpha update rate: 0.1400
# Iteration: 620
# Total alpha changes: 3465
# Alpha update rate: 0.1397
# Iteration: 630
# Total alpha changes: 3523
# Alpha update rate: 0.1398
# Iteration: 640
# Total alpha changes: 3578
# Alpha update rate: 0.1398
# Iteration: 650
# Total alpha changes: 3646
# Alpha update rate: 0.1402
# Iteration: 660
# Total alpha changes: 3705
# Alpha update rate: 0.1403
# Iteration: 670
# Total alpha changes: 3768
# Alpha update rate: 0.1406
# Iteration: 680
# Total alpha changes: 3813
# Alpha update rate: 0.1402
# Iteration: 690
# Total alpha changes: 3869
# Alpha update rate: 0.1402
# Iteration: 700
# Total alpha changes: 3925
# Alpha update rate: 0.1402
# Iteration: 710
# Total alpha changes: 3989
# Alpha update rate: 0.1405
# Iteration: 720
# Total alpha changes: 4051
# Alpha update rate: 0.1407
# Iteration: 730
# Total alpha changes: 4101
# Alpha update rate: 0.1404
# Iteration: 740
# Total alpha changes: 4162
# Alpha update rate: 0.1406
# Iteration: 750
# Total alpha changes: 4210
# Alpha update rate: 0.1403
# Iteration: 760
# Total alpha changes: 4266
# Alpha update rate: 0.1403
# Iteration: 770
# Total alpha changes: 4328
# Alpha update rate: 0.1405
# Iteration: 780
# Total alpha changes: 4394
# Alpha update rate: 0.1408
# Iteration: 790
# Total alpha changes: 4466
# Alpha update rate: 0.1413
# Iteration: 800
# Total alpha changes: 4510
# Alpha update rate: 0.1409
# Iteration: 810
# Total alpha changes: 4574
# Alpha update rate: 0.1412
# Iteration: 820
# Total alpha changes: 4628
# Alpha update rate: 0.1411
# Iteration: 830
# Total alpha changes: 4686
# Alpha update rate: 0.1411
# Iteration: 840
# Total alpha changes: 4752
# Alpha update rate: 0.1414
# Iteration: 850
# Total alpha changes: 4811
# Alpha update rate: 0.1415
# Iteration: 860
# Total alpha changes: 4868
# Alpha update rate: 0.1415
# Iteration: 870
# Total alpha changes: 4922
# Alpha update rate: 0.1414
# Iteration: 880
# Total alpha changes: 4969
# Alpha update rate: 0.1412
# Iteration: 890
# Total alpha changes: 5017
# Alpha update rate: 0.1409
# Iteration: 900
# Total alpha changes: 5078
# Alpha update rate: 0.1411
# Iteration: 910
# Total alpha changes: 5145
# Alpha update rate: 0.1413
# Iteration: 920
# Total alpha changes: 5205
# Alpha update rate: 0.1414
# Iteration: 930
# Total alpha changes: 5263
# Alpha update rate: 0.1415
# Iteration: 940
# Total alpha changes: 5329
# Alpha update rate: 0.1417
# Iteration: 950
# Total alpha changes: 5388
# Alpha update rate: 0.1418
# Iteration: 960
# Total alpha changes: 5454
# Alpha update rate: 0.1420
# Iteration: 970
# Total alpha changes: 5507
# Alpha update rate: 0.1419
# Iteration: 980
# Total alpha changes: 5560
# Alpha update rate: 0.1418
# Iteration: 990
# Total alpha changes: 5614
# Alpha update rate: 0.1418
# [<matplotlib.lines.Line2D at 0x11a2c9f90>,
#  <matplotlib.lines.Line2D at 0x11e0810d0>]

# %% [markdown]
# ### Plotting the alphas in 3D

# %%
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly.graph_objs as go

alphas_softmax_proposed = np.zeros(shape=history_alpha.shape)

diff_min = 10000
idx_min = -1
for it, alpha_it in enumerate(history_alpha):
    for t, alpha_proposed_t in enumerate(alpha_it):
        alphas_softmax_proposed[it][t] = softmax(alpha_proposed_t)
    diff_abs = np.abs(alphas_softmax - alphas_softmax_proposed[it]).sum()
    if diff_abs < diff_min:
        diff_min = diff_abs
        idx_min = it
    
n_alphas = alphas_softmax_proposed.shape[2]
list_alphas = []
for i in range(n_alphas):
    alpha = dict(z = alphas_softmax_proposed[:, :, i], type='surface')
    list_alphas.append(alpha)
fig = go.Figure(data=list_alphas)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perdaugmazas/325.embed" height="525px" width="100%"></iframe>
