# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
np.set_printoptions(threshold=np.nan)
import matplotlib.pyplot as plt
# %matplotlib inline

def softmax(arr):
    return np.exp(arr) / np.sum(np.exp(arr))

## Corpus parameters
K = 2
xi = 1000 # Approximate number of words
T = 20
linspace_t = np.linspace(0, T-1, num=T)
V = 10

## Random Betas
# prior_dirichlet = np.repeat(1./V, V)
# beta = np.random.dirichlet(prior_dirichlet, K)

beta = np.array([[0, 0, 0, 0.3, 0.7, 0, 0, 0, 0, 0], [0, 0, 0.2, 0, 0, 0, 0, 0.3, 0.3, 0.2]])

alphas = np.zeros((T, K))
linspace_4pi = np.linspace(0, 4*np.pi, num=T)
alphas[:,0] = np.sin(linspace_4pi) 
alphas[:,1] = np.cos(linspace_4pi)

# %% [markdown]
# ### Generate a corpus

# %%
import string

## Initialise the vocabulary
vocab = []
for w in range(V):
    vocab.append(string.ascii_lowercase[w])

corpus = {}
for d in range(T):
    corpus[d] = {}
    N = np.random.poisson(xi)
    for w in range(N):
        theta = softmax(alphas[d])
#         topic_distrib = np.random.multinomial(1, theta)
        topic_distrib = np.random.multinomial(1, alphas[d])
        z = np.where(topic_distrib == 1)[0][0]
        word_distrib = np.random.multinomial(1, beta[z])
        w = np.where(word_distrib == 1)[0][0]
        w_key = vocab[w]
        if w_key not in corpus[d]:
            corpus[d][w_key] = 0
        corpus[d][w_key] += 1

from preprocessing import preprocess_corpus
count_max = 200.
normalise = False
corpus = preprocess_corpus(corpus, vocab, threshold=count_max, normalise=normalise)
# corpus.dump('corpus_test.pkl')

# %% [markdown]
# ### Import the corpus

# %%
corpus = pd.read_pickle('corpus_test.pkl')

# %% [markdown]
# ### Visualise the betas

# %%
linspace_V = np.linspace(0, V-1, num=V)

plt.figure(1)
plt.bar(linspace_V, beta[0], label='k=0')
plt.bar(linspace_V, beta[1], label='k=1')
plt.xticks(np.arange(0, 10, 1.0))
plt.legend(loc=1)
plt.xlabel('V')
plt.ylabel(r'$\beta$')
plt.savefig('betas.png')

# %% [markdown]
# ### Visualise the thetas

# %%
from matplotlib.ticker import MaxNLocator
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

alphas_softmax = np.zeros(shape=alphas.shape)
for t, alpha_t in enumerate(alphas):
    alphas_softmax[t] = softmax(alpha_t)
alphas_softmax = alphas_softmax.T
labels = ['k=0', 'k=1']
for y_arr, label in zip(alphas_softmax, labels):
    plt.plot(linspace_t, y_arr, label=label)

plt.xlabel('t')
plt.ylabel(r'softmax($\alpha$)')
plt.legend(loc=1)
plt.savefig('mu.png')

# %% [markdown]
# ### Fit

# %%
from dtm_alpha import DTM_Alpha

n_it = 2000
var_init = 5
var_basic = 0.01
var_prop = 1
autoreg = True
dtm_alpha = DTM_Alpha(K=K, sigma_0_sq=var_init, sigma_sq=var_basic, 
        delta_sq=var_prop, autoreg=autoreg)
dtm_alpha.beta = beta
dtm_alpha.fit(corpus=corpus, n_it=n_it)
# Out:
# Iteration: 10
# Total alpha changes: 92
# Alpha update rate: 0.2300
# Iteration: 20
# Total alpha changes: 187
# Alpha update rate: 0.2338
# Iteration: 30
# Total alpha changes: 292
# Alpha update rate: 0.2433
# Iteration: 40
# Total alpha changes: 402
# Alpha update rate: 0.2512
# Iteration: 50
# Total alpha changes: 519
# Alpha update rate: 0.2595
# Iteration: 60
# Total alpha changes: 656
# Alpha update rate: 0.2733
# Iteration: 70
# Total alpha changes: 774
# Alpha update rate: 0.2764
# Iteration: 80
# Total alpha changes: 891
# Alpha update rate: 0.2784
# Iteration: 90
# Total alpha changes: 1011
# Alpha update rate: 0.2808
# Iteration: 100
# Total alpha changes: 1124
# Alpha update rate: 0.2810
# Iteration: 110
# Total alpha changes: 1238
# Alpha update rate: 0.2814
# Iteration: 120
# Total alpha changes: 1354
# Alpha update rate: 0.2821
# Iteration: 130
# Total alpha changes: 1477
# Alpha update rate: 0.2840
# Iteration: 140
# Total alpha changes: 1607
# Alpha update rate: 0.2870
# Iteration: 150
# Total alpha changes: 1721
# Alpha update rate: 0.2868
# Iteration: 160
# Total alpha changes: 1844
# Alpha update rate: 0.2881
# Iteration: 170
# Total alpha changes: 1953
# Alpha update rate: 0.2872
# Iteration: 180
# Total alpha changes: 2073
# Alpha update rate: 0.2879
# Iteration: 190
# Total alpha changes: 2190
# Alpha update rate: 0.2882
# Iteration: 200
# Total alpha changes: 2310
# Alpha update rate: 0.2888
# Iteration: 210
# Total alpha changes: 2429
# Alpha update rate: 0.2892
# Iteration: 220
# Total alpha changes: 2543
# Alpha update rate: 0.2890
# Iteration: 230
# Total alpha changes: 2667
# Alpha update rate: 0.2899
# Iteration: 240
# Total alpha changes: 2776
# Alpha update rate: 0.2892
# Iteration: 250
# Total alpha changes: 2894
# Alpha update rate: 0.2894
# Iteration: 260
# Total alpha changes: 3021
# Alpha update rate: 0.2905
# Iteration: 270
# Total alpha changes: 3145
# Alpha update rate: 0.2912
# Iteration: 280
# Total alpha changes: 3257
# Alpha update rate: 0.2908
# Iteration: 290
# Total alpha changes: 3382
# Alpha update rate: 0.2916
# Iteration: 300
# Total alpha changes: 3502
# Alpha update rate: 0.2918
# Iteration: 310
# Total alpha changes: 3630
# Alpha update rate: 0.2927
# Iteration: 320
# Total alpha changes: 3758
# Alpha update rate: 0.2936
# Iteration: 330
# Total alpha changes: 3870
# Alpha update rate: 0.2932
# Iteration: 340
# Total alpha changes: 3991
# Alpha update rate: 0.2935
# Iteration: 350
# Total alpha changes: 4103
# Alpha update rate: 0.2931
# Iteration: 360
# Total alpha changes: 4211
# Alpha update rate: 0.2924
# Iteration: 370
# Total alpha changes: 4323
# Alpha update rate: 0.2921
# Iteration: 380
# Total alpha changes: 4436
# Alpha update rate: 0.2918
# Iteration: 390
# Total alpha changes: 4562
# Alpha update rate: 0.2924
# Iteration: 400
# Total alpha changes: 4674
# Alpha update rate: 0.2921
# Iteration: 410
# Total alpha changes: 4793
# Alpha update rate: 0.2923
# Iteration: 420
# Total alpha changes: 4905
# Alpha update rate: 0.2920
# Iteration: 430
# Total alpha changes: 5025
# Alpha update rate: 0.2922
# Iteration: 440
# Total alpha changes: 5145
# Alpha update rate: 0.2923
# Iteration: 450
# Total alpha changes: 5260
# Alpha update rate: 0.2922
# Iteration: 460
# Total alpha changes: 5378
# Alpha update rate: 0.2923
# Iteration: 470
# Total alpha changes: 5504
# Alpha update rate: 0.2928
# Iteration: 480
# Total alpha changes: 5623
# Alpha update rate: 0.2929
# Iteration: 490
# Total alpha changes: 5740
# Alpha update rate: 0.2929
# Iteration: 500
# Total alpha changes: 5859
# Alpha update rate: 0.2929
# Iteration: 510
# Total alpha changes: 5981
# Alpha update rate: 0.2932
# Iteration: 520
# Total alpha changes: 6106
# Alpha update rate: 0.2936
# Iteration: 530
# Total alpha changes: 6230
# Alpha update rate: 0.2939
# Iteration: 540
# Total alpha changes: 6345
# Alpha update rate: 0.2938
# Iteration: 550
# Total alpha changes: 6455
# Alpha update rate: 0.2934
# Iteration: 560
# Total alpha changes: 6576
# Alpha update rate: 0.2936
# Iteration: 570
# Total alpha changes: 6681
# Alpha update rate: 0.2930
# Iteration: 580
# Total alpha changes: 6817
# Alpha update rate: 0.2938
# Iteration: 590
# Total alpha changes: 6947
# Alpha update rate: 0.2944
# Iteration: 600
# Total alpha changes: 7056
# Alpha update rate: 0.2940
# Iteration: 610
# Total alpha changes: 7164
# Alpha update rate: 0.2936
# Iteration: 620
# Total alpha changes: 7299
# Alpha update rate: 0.2943
# Iteration: 630
# Total alpha changes: 7422
# Alpha update rate: 0.2945
# Iteration: 640
# Total alpha changes: 7546
# Alpha update rate: 0.2948
# Iteration: 650
# Total alpha changes: 7670
# Alpha update rate: 0.2950
# Iteration: 660
# Total alpha changes: 7790
# Alpha update rate: 0.2951
# Iteration: 670
# Total alpha changes: 7907
# Alpha update rate: 0.2950
# Iteration: 680
# Total alpha changes: 8032
# Alpha update rate: 0.2953
# Iteration: 690
# Total alpha changes: 8155
# Alpha update rate: 0.2955
# Iteration: 700
# Total alpha changes: 8277
# Alpha update rate: 0.2956
# Iteration: 710
# Total alpha changes: 8400
# Alpha update rate: 0.2958
# Iteration: 720
# Total alpha changes: 8509
# Alpha update rate: 0.2955
# Iteration: 730
# Total alpha changes: 8630
# Alpha update rate: 0.2955
# Iteration: 740
# Total alpha changes: 8765
# Alpha update rate: 0.2961
# Iteration: 750
# Total alpha changes: 8888
# Alpha update rate: 0.2963
# Iteration: 760
# Total alpha changes: 9020
# Alpha update rate: 0.2967
# Iteration: 770
# Total alpha changes: 9148
# Alpha update rate: 0.2970
# Iteration: 780
# Total alpha changes: 9265
# Alpha update rate: 0.2970
# Iteration: 790
# Total alpha changes: 9383
# Alpha update rate: 0.2969
# Iteration: 800
# Total alpha changes: 9502
# Alpha update rate: 0.2969
# Iteration: 810
# Total alpha changes: 9617
# Alpha update rate: 0.2968
# Iteration: 820
# Total alpha changes: 9755
# Alpha update rate: 0.2974
# Iteration: 830
# Total alpha changes: 9879
# Alpha update rate: 0.2976
# Iteration: 840
# Total alpha changes: 10000
# Alpha update rate: 0.2976
# Iteration: 850
# Total alpha changes: 10130
# Alpha update rate: 0.2979
# Iteration: 860
# Total alpha changes: 10270
# Alpha update rate: 0.2985
# Iteration: 870
# Total alpha changes: 10397
# Alpha update rate: 0.2988
# Iteration: 880
# Total alpha changes: 10513
# Alpha update rate: 0.2987
# Iteration: 890
# Total alpha changes: 10649
# Alpha update rate: 0.2991
# Iteration: 900
# Total alpha changes: 10777
# Alpha update rate: 0.2994
# Iteration: 910
# Total alpha changes: 10888
# Alpha update rate: 0.2991
# Iteration: 920
# Total alpha changes: 11022
# Alpha update rate: 0.2995
# Iteration: 930
# Total alpha changes: 11157
# Alpha update rate: 0.2999
# Iteration: 940
# Total alpha changes: 11266
# Alpha update rate: 0.2996
# Iteration: 950
# Total alpha changes: 11384
# Alpha update rate: 0.2996
# Iteration: 960
# Total alpha changes: 11511
# Alpha update rate: 0.2998
# Iteration: 970
# Total alpha changes: 11636
# Alpha update rate: 0.2999
# Iteration: 980
# Total alpha changes: 11750
# Alpha update rate: 0.2997
# Iteration: 990
# Total alpha changes: 11873
# Alpha update rate: 0.2998
# Iteration: 1000
# Total alpha changes: 11986
# Alpha update rate: 0.2997
# Iteration: 1010
# Total alpha changes: 12139
# Alpha update rate: 0.3005
# Iteration: 1020
# Total alpha changes: 12254
# Alpha update rate: 0.3003
# Iteration: 1030
# Total alpha changes: 12383
# Alpha update rate: 0.3006
# Iteration: 1040
# Total alpha changes: 12497
# Alpha update rate: 0.3004
# Iteration: 1050
# Total alpha changes: 12622
# Alpha update rate: 0.3005
# Iteration: 1060
# Total alpha changes: 12749
# Alpha update rate: 0.3007
# Iteration: 1070
# Total alpha changes: 12876
# Alpha update rate: 0.3008
# Iteration: 1080
# Total alpha changes: 13004
# Alpha update rate: 0.3010
# Iteration: 1090
# Total alpha changes: 13131
# Alpha update rate: 0.3012
# Iteration: 1100
# Total alpha changes: 13254
# Alpha update rate: 0.3012
# Iteration: 1110
# Total alpha changes: 13380
# Alpha update rate: 0.3014
# Iteration: 1120
# Total alpha changes: 13516
# Alpha update rate: 0.3017
# Iteration: 1130
# Total alpha changes: 13633
# Alpha update rate: 0.3016
# Iteration: 1140
# Total alpha changes: 13764
# Alpha update rate: 0.3018
# Iteration: 1150
# Total alpha changes: 13875
# Alpha update rate: 0.3016
# Iteration: 1160
# Total alpha changes: 14014
# Alpha update rate: 0.3020
# Iteration: 1170
# Total alpha changes: 14154
# Alpha update rate: 0.3024
# Iteration: 1180
# Total alpha changes: 14269
# Alpha update rate: 0.3023
# Iteration: 1190
# Total alpha changes: 14398
# Alpha update rate: 0.3025
# Iteration: 1200
# Total alpha changes: 14525
# Alpha update rate: 0.3026
# Iteration: 1210
# Total alpha changes: 14645
# Alpha update rate: 0.3026
# Iteration: 1220
# Total alpha changes: 14762
# Alpha update rate: 0.3025
# Iteration: 1230
# Total alpha changes: 14874
# Alpha update rate: 0.3023
# Iteration: 1240
# Total alpha changes: 15001
# Alpha update rate: 0.3024
# Iteration: 1250
# Total alpha changes: 15119
# Alpha update rate: 0.3024
# Iteration: 1260
# Total alpha changes: 15246
# Alpha update rate: 0.3025
# Iteration: 1270
# Total alpha changes: 15355
# Alpha update rate: 0.3023
# Iteration: 1280
# Total alpha changes: 15486
# Alpha update rate: 0.3025
# Iteration: 1290
# Total alpha changes: 15594
# Alpha update rate: 0.3022
# Iteration: 1300
# Total alpha changes: 15726
# Alpha update rate: 0.3024
# Iteration: 1310
# Total alpha changes: 15855
# Alpha update rate: 0.3026
# Iteration: 1320
# Total alpha changes: 15981
# Alpha update rate: 0.3027
# Iteration: 1330
# Total alpha changes: 16110
# Alpha update rate: 0.3028
# Iteration: 1340
# Total alpha changes: 16238
# Alpha update rate: 0.3029
# Iteration: 1350
# Total alpha changes: 16373
# Alpha update rate: 0.3032
# Iteration: 1360
# Total alpha changes: 16495
# Alpha update rate: 0.3032
# Iteration: 1370
# Total alpha changes: 16618
# Alpha update rate: 0.3032
# Iteration: 1380
# Total alpha changes: 16739
# Alpha update rate: 0.3032
# Iteration: 1390
# Total alpha changes: 16857
# Alpha update rate: 0.3032
# Iteration: 1400
# Total alpha changes: 16984
# Alpha update rate: 0.3033
# Iteration: 1410
# Total alpha changes: 17115
# Alpha update rate: 0.3035
# Iteration: 1420
# Total alpha changes: 17241
# Alpha update rate: 0.3035
# Iteration: 1430
# Total alpha changes: 17382
# Alpha update rate: 0.3039
# Iteration: 1440
# Total alpha changes: 17493
# Alpha update rate: 0.3037
# Iteration: 1450
# Total alpha changes: 17622
# Alpha update rate: 0.3038
# Iteration: 1460
# Total alpha changes: 17739
# Alpha update rate: 0.3038
# Iteration: 1470
# Total alpha changes: 17874
# Alpha update rate: 0.3040
# Iteration: 1480
# Total alpha changes: 17992
# Alpha update rate: 0.3039
# Iteration: 1490
# Total alpha changes: 18111
# Alpha update rate: 0.3039
# Iteration: 1500
# Total alpha changes: 18244
# Alpha update rate: 0.3041
# Iteration: 1510
# Total alpha changes: 18368
# Alpha update rate: 0.3041
# Iteration: 1520
# Total alpha changes: 18499
# Alpha update rate: 0.3043
# Iteration: 1530
# Total alpha changes: 18617
# Alpha update rate: 0.3042
# Iteration: 1540
# Total alpha changes: 18740
# Alpha update rate: 0.3042
# Iteration: 1550
# Total alpha changes: 18864
# Alpha update rate: 0.3043
# Iteration: 1560
# Total alpha changes: 18992
# Alpha update rate: 0.3044
# Iteration: 1570
# Total alpha changes: 19113
# Alpha update rate: 0.3043
# Iteration: 1580
# Total alpha changes: 19226
# Alpha update rate: 0.3042
# Iteration: 1590
# Total alpha changes: 19347
# Alpha update rate: 0.3042
# Iteration: 1600
# Total alpha changes: 19464
# Alpha update rate: 0.3041
# Iteration: 1610
# Total alpha changes: 19607
# Alpha update rate: 0.3045
# Iteration: 1620
# Total alpha changes: 19733
# Alpha update rate: 0.3045
# Iteration: 1630
# Total alpha changes: 19862
# Alpha update rate: 0.3046
# Iteration: 1640
# Total alpha changes: 19994
# Alpha update rate: 0.3048
# Iteration: 1650
# Total alpha changes: 20119
# Alpha update rate: 0.3048
# Iteration: 1660
# Total alpha changes: 20239
# Alpha update rate: 0.3048
# Iteration: 1670
# Total alpha changes: 20364
# Alpha update rate: 0.3049
# Iteration: 1680
# Total alpha changes: 20476
# Alpha update rate: 0.3047
# Iteration: 1690
# Total alpha changes: 20602
# Alpha update rate: 0.3048
# Iteration: 1700
# Total alpha changes: 20716
# Alpha update rate: 0.3046
# Iteration: 1710
# Total alpha changes: 20839
# Alpha update rate: 0.3047
# Iteration: 1720
# Total alpha changes: 20972
# Alpha update rate: 0.3048
# Iteration: 1730
# Total alpha changes: 21092
# Alpha update rate: 0.3048
# Iteration: 1740
# Total alpha changes: 21212
# Alpha update rate: 0.3048
# Iteration: 1750
# Total alpha changes: 21320
# Alpha update rate: 0.3046
# Iteration: 1760
# Total alpha changes: 21455
# Alpha update rate: 0.3048
# Iteration: 1770
# Total alpha changes: 21581
# Alpha update rate: 0.3048
# Iteration: 1780
# Total alpha changes: 21714
# Alpha update rate: 0.3050
# Iteration: 1790
# Total alpha changes: 21846
# Alpha update rate: 0.3051
# Iteration: 1800
# Total alpha changes: 21969
# Alpha update rate: 0.3051
# Iteration: 1810
# Total alpha changes: 22093
# Alpha update rate: 0.3052
# Iteration: 1820
# Total alpha changes: 22224
# Alpha update rate: 0.3053
# Iteration: 1830
# Total alpha changes: 22352
# Alpha update rate: 0.3054
# Iteration: 1840
# Total alpha changes: 22484
# Alpha update rate: 0.3055
# Iteration: 1850
# Total alpha changes: 22622
# Alpha update rate: 0.3057
# Iteration: 1860
# Total alpha changes: 22747
# Alpha update rate: 0.3057
# Iteration: 1870
# Total alpha changes: 22861
# Alpha update rate: 0.3056
# Iteration: 1880
# Total alpha changes: 22970
# Alpha update rate: 0.3055
# Iteration: 1890
# Total alpha changes: 23101
# Alpha update rate: 0.3056
# Iteration: 1900
# Total alpha changes: 23212
# Alpha update rate: 0.3054
# Iteration: 1910
# Total alpha changes: 23335
# Alpha update rate: 0.3054
# Iteration: 1920
# Total alpha changes: 23450
# Alpha update rate: 0.3053
# Iteration: 1930
# Total alpha changes: 23565
# Alpha update rate: 0.3052
# Iteration: 1940
# Total alpha changes: 23684
# Alpha update rate: 0.3052
# Iteration: 1950
# Total alpha changes: 23809
# Alpha update rate: 0.3052
# Iteration: 1960
# Total alpha changes: 23938
# Alpha update rate: 0.3053
# Iteration: 1970
# Total alpha changes: 24058
# Alpha update rate: 0.3053
# Iteration: 1980
# Total alpha changes: 24194
# Alpha update rate: 0.3055
# Iteration: 1990
# Total alpha changes: 24320
# Alpha update rate: 0.3055

# %% [markdown]
# ### Print and dump

# %%
# Calculate the softmax
history_alpha = dtm_alpha.hist_alpha
labels = []
curves = []
settings = []
colours = ['orange', 'b']
for it in xrange(0, 2):
    idx = n_it - int(it * n_it/2)
    alphas_last_proposed = history_alpha[idx-1]
    alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
    for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
        alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)
    alphas_softmax_last_proposed = alphas_softmax_last_proposed.T
    for id_label, alpha in enumerate(alphas_softmax_last_proposed):
        curves.append(alpha)
        settings.append((colours[id_label],1-(it*0.5)))
        labels.append('k=%d, it=%d' % (id_label, idx))

# Plot the figure
from matplotlib.ticker import MaxNLocator
ax = plt.figure().gca()
ax.xaxis.set_major_locator(MaxNLocator(integer=True))

for y_arr, label, setting in zip(curves, labels, settings):
    plt.plot(linspace_t, y_arr, label=label, color=setting[0], alpha=setting[1])
title_fig = r'$\sigma_0^2=%.2f,\quad \sigma^2=%.4f,\quad \delta^2=%.1f$' \
        % (var_init, var_basic, var_prop)
plt.title(title_fig)
plt.legend(loc=1)
plt.xlabel('t')
plt.ylabel(r'$\theta$')

# Save the plot and the model
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it, str(autoreg))
plt.savefig('results/' + name_model_out + '.png', dpi=300)
vars_dtm = vars(dtm_alpha)
with open('models/' + name_model_out + '.pkl', 'wb') as f:
        pkl.dump(vars_dtm, f)

# %% [markdown]
# ### Load, fit, and dump

# %%
# from dtm_alpha import DTM_Alpha

n_it = 500
n_it_add = 500
var_init = 1
var_basic = 0.001
var_prop = 1
autoreg=True
name_model_in = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it, str(autoreg))
name_model_out = 'init_%.0E|basic_%.0E|prop_%.0E|it_%d|autoreg_%s' \
        % (var_init, var_basic, var_prop, n_it + n_it_add, str(autoreg))

dtm_alpha = DTM_Alpha()
dtm_alpha.load_fit('models/' + name_model_in + '.pkl', n_it=n_it_add)

history_alpha = dtm_alpha.hist_alpha
alphas_last_proposed = history_alpha[n_it-1]
alphas_softmax_last_proposed = np.zeros(shape=alphas_last_proposed.shape)
for t, alphas_last_proposed_t in enumerate(alphas_last_proposed):
    alphas_softmax_last_proposed[t] = softmax(alphas_last_proposed_t)

plt.plot(linspace_t, alphas_softmax_last_proposed, linewidth=2)

## Save the results
# plt.savefig('results/' + name_model_out + '.png')
# vars_dtm = vars(dtm_alpha)
# with open('models/' + name_model_out + '.pkl', 'wb') as f:
#         pkl.dump(vars_dtm, f)
# Out:
# Iteration: 500
# Total alpha changes: 2796
# Alpha update rate: 0.1398
# Iteration: 510
# Total alpha changes: 2841
# Alpha update rate: 0.1393
# Iteration: 520
# Total alpha changes: 2903
# Alpha update rate: 0.1396
# Iteration: 530
# Total alpha changes: 2957
# Alpha update rate: 0.1395
# Iteration: 540
# Total alpha changes: 3022
# Alpha update rate: 0.1399
# Iteration: 550
# Total alpha changes: 3087
# Alpha update rate: 0.1403
# Iteration: 560
# Total alpha changes: 3138
# Alpha update rate: 0.1401
# Iteration: 570
# Total alpha changes: 3186
# Alpha update rate: 0.1397
# Iteration: 580
# Total alpha changes: 3242
# Alpha update rate: 0.1397
# Iteration: 590
# Total alpha changes: 3297
# Alpha update rate: 0.1397
# Iteration: 600
# Total alpha changes: 3362
# Alpha update rate: 0.1401
# Iteration: 610
# Total alpha changes: 3416
# Alpha update rate: 0.1400
# Iteration: 620
# Total alpha changes: 3465
# Alpha update rate: 0.1397
# Iteration: 630
# Total alpha changes: 3523
# Alpha update rate: 0.1398
# Iteration: 640
# Total alpha changes: 3578
# Alpha update rate: 0.1398
# Iteration: 650
# Total alpha changes: 3646
# Alpha update rate: 0.1402
# Iteration: 660
# Total alpha changes: 3705
# Alpha update rate: 0.1403
# Iteration: 670
# Total alpha changes: 3768
# Alpha update rate: 0.1406
# Iteration: 680
# Total alpha changes: 3813
# Alpha update rate: 0.1402
# Iteration: 690
# Total alpha changes: 3869
# Alpha update rate: 0.1402
# Iteration: 700
# Total alpha changes: 3925
# Alpha update rate: 0.1402
# Iteration: 710
# Total alpha changes: 3989
# Alpha update rate: 0.1405
# Iteration: 720
# Total alpha changes: 4051
# Alpha update rate: 0.1407
# Iteration: 730
# Total alpha changes: 4101
# Alpha update rate: 0.1404
# Iteration: 740
# Total alpha changes: 4162
# Alpha update rate: 0.1406
# Iteration: 750
# Total alpha changes: 4210
# Alpha update rate: 0.1403
# Iteration: 760
# Total alpha changes: 4266
# Alpha update rate: 0.1403
# Iteration: 770
# Total alpha changes: 4328
# Alpha update rate: 0.1405
# Iteration: 780
# Total alpha changes: 4394
# Alpha update rate: 0.1408
# Iteration: 790
# Total alpha changes: 4466
# Alpha update rate: 0.1413
# Iteration: 800
# Total alpha changes: 4510
# Alpha update rate: 0.1409
# Iteration: 810
# Total alpha changes: 4574
# Alpha update rate: 0.1412
# Iteration: 820
# Total alpha changes: 4628
# Alpha update rate: 0.1411
# Iteration: 830
# Total alpha changes: 4686
# Alpha update rate: 0.1411
# Iteration: 840
# Total alpha changes: 4752
# Alpha update rate: 0.1414
# Iteration: 850
# Total alpha changes: 4811
# Alpha update rate: 0.1415
# Iteration: 860
# Total alpha changes: 4868
# Alpha update rate: 0.1415
# Iteration: 870
# Total alpha changes: 4922
# Alpha update rate: 0.1414
# Iteration: 880
# Total alpha changes: 4969
# Alpha update rate: 0.1412
# Iteration: 890
# Total alpha changes: 5017
# Alpha update rate: 0.1409
# Iteration: 900
# Total alpha changes: 5078
# Alpha update rate: 0.1411
# Iteration: 910
# Total alpha changes: 5145
# Alpha update rate: 0.1413
# Iteration: 920
# Total alpha changes: 5205
# Alpha update rate: 0.1414
# Iteration: 930
# Total alpha changes: 5263
# Alpha update rate: 0.1415
# Iteration: 940
# Total alpha changes: 5329
# Alpha update rate: 0.1417
# Iteration: 950
# Total alpha changes: 5388
# Alpha update rate: 0.1418
# Iteration: 960
# Total alpha changes: 5454
# Alpha update rate: 0.1420
# Iteration: 970
# Total alpha changes: 5507
# Alpha update rate: 0.1419
# Iteration: 980
# Total alpha changes: 5560
# Alpha update rate: 0.1418
# Iteration: 990
# Total alpha changes: 5614
# Alpha update rate: 0.1418
# [<matplotlib.lines.Line2D at 0x11a2c9f90>,
#  <matplotlib.lines.Line2D at 0x11e0810d0>]

# %% [markdown]
# ### Plotting the alphas in 3D

# %%
import plotly.plotly as py
from plotly.graph_objs import Surface
import plotly.graph_objs as go

alphas_softmax_proposed = np.zeros(shape=history_alpha.shape)

diff_min = 10000
idx_min = -1
for it, alpha_it in enumerate(history_alpha):
    for t, alpha_proposed_t in enumerate(alpha_it):
        alphas_softmax_proposed[it][t] = softmax(alpha_proposed_t)
    diff_abs = np.abs(alphas_softmax - alphas_softmax_proposed[it]).sum()
    if diff_abs < diff_min:
        diff_min = diff_abs
        idx_min = it
    
n_alphas = alphas_softmax_proposed.shape[2]
list_alphas = []
for i in range(n_alphas):
    alpha = dict(z = alphas_softmax_proposed[:, :, i], type='surface')
    list_alphas.append(alpha)
fig = go.Figure(data=list_alphas)

py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~perdaugmazas/325.embed" height="525px" width="100%"></iframe>
